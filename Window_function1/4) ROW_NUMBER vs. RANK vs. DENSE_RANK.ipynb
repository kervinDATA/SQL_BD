# %%
import pandas as pd
import duckdb

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
data = {
    'name': ['Toufik', 'Jean-Nicolas', 'Daniel', 'Kaouter', 'Sylvie',
             'Sebastien', 'Diane', 'Romain', 'François', 'Anna',
             'Zeinaba', 'Gregory', 'Karima', 'Arthur', 'Benjamin'],
    'wage': [60000, 75000, 55000, 100000, 70000,
             90000, 65000, 100000, 68000, 85000,
             100000, 120000, 95000, 83000, 110000],
    'department': ['IT', 'HR', 'SALES', 'IT', 'IT',
                   'HR', 'SALES', 'IT', 'HR', 'SALES',
                   'IT', 'IT', 'HR', 'SALES', 'CEO'],
    'sex': ['H', 'H', 'H', 'F', 'F',
           'H', 'F', 'H', 'H', 'F',
           'F', 'H', 'F', 'H', 'H',]
}
wages = pd.DataFrame(data)
wages.head()
# Out:
#            name    wage department sex
# 0        Toufik   60000         IT   H
# 1  Jean-Nicolas   75000         HR   H
# 2        Daniel   55000      SALES   H
# 3       Kaouter  100000         IT   F
# 4        Sylvie   70000         IT   F

# %% [markdown]
# Obtenir l'index:

# %%
query = """
SELECT *,
ROW_NUMBER() OVER() AS index
FROM wages
ORDER BY department
"""
duckdb.sql(query).df().head(10)
# Out:
#            name    wage department sex  index
# 0      Benjamin  110000        CEO   H     15
# 1  Jean-Nicolas   75000         HR   H      2
# 2     Sebastien   90000         HR   H      6
# 3      François   68000         HR   H      9
# 4        Karima   95000         HR   F     13
# 5        Toufik   60000         IT   H      1
# 6       Kaouter  100000         IT   F      4
# 7        Sylvie   70000         IT   F      5
# 8        Romain  100000         IT   H      8
# 9       Zeinaba  100000         IT   F     11

# %% [markdown]
# Le numéro de ligne par département:

# %%
query = """
SELECT *,
ROW_NUMBER() OVER(PARTITION BY department) AS index
FROM wages
"""
duckdb.sql(query).df().head(10)
# Out:
#        name    wage department sex  index
# 0    Toufik   60000         IT   H      1
# 1   Kaouter  100000         IT   F      2
# 2    Sylvie   70000         IT   F      3
# 3    Romain  100000         IT   H      4
# 4   Zeinaba  100000         IT   F      5
# 5   Gregory  120000         IT   H      6
# 6  Benjamin  110000        CEO   H      1
# 7    Daniel   55000      SALES   H      1
# 8     Diane   65000      SALES   F      2
# 9      Anna   85000      SALES   F      3

# %% [markdown]
# Exercice: obtenez le classement entre les hommes et les femmes

# %%
query = """
SELECT *,
ROW_NUMBER() OVER(PARTITION BY sex) AS index
FROM wages

"""
duckdb.sql(query).df()
# Out:
#             name    wage department sex  index
# 0         Toufik   60000         IT   H      1
# 1   Jean-Nicolas   75000         HR   H      2
# 2         Daniel   55000      SALES   H      3
# 3      Sebastien   90000         HR   H      4
# 4         Romain  100000         IT   H      5
# 5       François   68000         HR   H      6
# 6        Gregory  120000         IT   H      7
# 7         Arthur   83000      SALES   H      8
# 8       Benjamin  110000        CEO   H      9
# 9        Kaouter  100000         IT   F      1
# 10        Sylvie   70000         IT   F      2
# 11         Diane   65000      SALES   F      3
# 12          Anna   85000      SALES   F      4
# 13       Zeinaba  100000         IT   F      5
# 14        Karima   95000         HR   F      6

# %%
# %load solutions/14row_number_by_sex.py
query = """
SELECT *,
ROW_NUMBER() OVER(
    PARTITION BY sex
    ) AS index
FROM wages
"""
duckdb.sql(query).df().head(11)
# Out:
#             name    wage department sex  index
# 0         Toufik   60000         IT   H      1
# 1   Jean-Nicolas   75000         HR   H      2
# 2         Daniel   55000      SALES   H      3
# 3      Sebastien   90000         HR   H      4
# 4         Romain  100000         IT   H      5
# 5       François   68000         HR   H      6
# 6        Gregory  120000         IT   H      7
# 7         Arthur   83000      SALES   H      8
# 8       Benjamin  110000        CEO   H      9
# 9        Kaouter  100000         IT   F      1
# 10        Sylvie   70000         IT   F      2

# %% [markdown]
# Le numéro de ligne par département, du plus gros au plus petit salaire:

# %%
query = """
SELECT *,
ROW_NUMBER() OVER(PARTITION BY department ORDER BY wage DESC) AS index
FROM wages

"""
duckdb.sql(query).df()
# Out:
#             name    wage department sex  index
# 0        Gregory  120000         IT   H      1
# 1        Kaouter  100000         IT   F      2
# 2         Romain  100000         IT   H      3
# 3        Zeinaba  100000         IT   F      4
# 4         Sylvie   70000         IT   F      5
# 5         Toufik   60000         IT   H      6
# 6         Karima   95000         HR   F      1
# 7      Sebastien   90000         HR   H      2
# 8   Jean-Nicolas   75000         HR   H      3
# 9       François   68000         HR   H      4
# 10          Anna   85000      SALES   F      1
# 11        Arthur   83000      SALES   H      2
# 12         Diane   65000      SALES   F      3
# 13        Daniel   55000      SALES   H      4
# 14      Benjamin  110000        CEO   H      1

# %%
# %load solutions/15row_number_by_dpt_order_by_wage.py
query = """
SELECT *,
ROW_NUMBER() OVER(
    PARTITION BY department
    ORDER BY wage DESC
    ) AS index
FROM wages
LIMIT 10
"""
duckdb.sql(query).df()
# Out:
#            name    wage department sex  index
# 0       Gregory  120000         IT   H      1
# 1       Kaouter  100000         IT   F      2
# 2        Romain  100000         IT   H      3
# 3       Zeinaba  100000         IT   F      4
# 4        Sylvie   70000         IT   F      5
# 5        Toufik   60000         IT   H      6
# 6        Karima   95000         HR   F      1
# 7     Sebastien   90000         HR   H      2
# 8  Jean-Nicolas   75000         HR   H      3
# 9      François   68000         HR   H      4

# %% [markdown]
# Ici, on peut s'apercevoir que Kaouter, Romain et Zeinaba ont le même salaire. <br />
# pourtant leur "row_number" continue de progresser.
#
# Clairement, ce n'est pas la fonction idéale pour gérer les classements...

# %% [markdown]
# Exercice avant de passer à la suite: obtenez le classement des salaires par sexe:

# %%
query = """
SELECT *,
ROW_NUMBER() OVER(PARTITION BY sex ORDER BY wage DESC) AS index
FROM wages

"""
duckdb.sql(query).df()
# Out:
#             name    wage department sex  index
# 0        Gregory  120000         IT   H      1
# 1       Benjamin  110000        CEO   H      2
# 2         Romain  100000         IT   H      3
# 3      Sebastien   90000         HR   H      4
# 4         Arthur   83000      SALES   H      5
# 5   Jean-Nicolas   75000         HR   H      6
# 6       François   68000         HR   H      7
# 7         Toufik   60000         IT   H      8
# 8         Daniel   55000      SALES   H      9
# 9        Kaouter  100000         IT   F      1
# 10       Zeinaba  100000         IT   F      2
# 11        Karima   95000         HR   F      3
# 12          Anna   85000      SALES   F      4
# 13        Sylvie   70000         IT   F      5
# 14         Diane   65000      SALES   F      6

# %%
# %load solutions/16row_number_by_sex_order_by_wage.py
query = """
SELECT *,
ROW_NUMBER() OVER(
    PARTITION BY sex
    ORDER BY wage DESC) 
AS index
FROM wages
LIMIT 10 
"""
duckdb.sql(query).df().head(11)
# Out:
#            name    wage department sex  index
# 0       Gregory  120000         IT   H      1
# 1      Benjamin  110000        CEO   H      2
# 2        Romain  100000         IT   H      3
# 3     Sebastien   90000         HR   H      4
# 4        Arthur   83000      SALES   H      5
# 5  Jean-Nicolas   75000         HR   H      6
# 6      François   68000         HR   H      7
# 7        Toufik   60000         IT   H      8
# 8        Daniel   55000      SALES   H      9
# 9       Kaouter  100000         IT   F      1

# %% [markdown]
# ### Comment gérer les égalités ? RANK vs. DENSE_RANK

# %%
query = """
SELECT *,
RANK() OVER(
    PARTITION BY department
    ORDER BY wage DESC) AS index
FROM wages
"""
duckdb.sql(query).df().head(10)
# Out:
#            name    wage department sex  index
# 0       Gregory  120000         IT   H      1
# 1       Kaouter  100000         IT   F      2
# 2        Romain  100000         IT   H      2
# 3       Zeinaba  100000         IT   F      2
# 4        Sylvie   70000         IT   F      5
# 5        Toufik   60000         IT   H      6
# 6        Karima   95000         HR   F      1
# 7     Sebastien   90000         HR   H      2
# 8  Jean-Nicolas   75000         HR   H      3
# 9      François   68000         HR   H      4

# %% [markdown]
# A comparer avec dense_rank :

# %%
query = """
SELECT *,
DENSE_RANK() OVER(
    PARTITION BY department 
    ORDER BY wage DESC) AS index
FROM wages
"""
duckdb.sql(query).df().head(10)
# Out:
#        name    wage department sex  index
# 0  Benjamin  110000        CEO   H      1
# 1   Gregory  120000         IT   H      1
# 2   Kaouter  100000         IT   F      2
# 3    Romain  100000         IT   H      2
# 4   Zeinaba  100000         IT   F      2
# 5    Sylvie   70000         IT   F      3
# 6    Toufik   60000         IT   H      4
# 7      Anna   85000      SALES   F      1
# 8    Arthur   83000      SALES   H      2
# 9     Diane   65000      SALES   F      3

# %% [markdown]
# Avez-vous trouvé la différence ?

# %% [markdown]
# Elle ne se situe pas au niveau du ranking des valeurs qui sont à égalité <br />
# La différence se situe au niveau des valeurs suivantes.
#
# - avec RANK, on obtient 1, 2, 2, 2, 5(!), 6(!): le classement reprends comme si les égalités avaient eu le rang 2, 3 ,4
# - avec DENSE_RANK, on obtient 1, 2, 2, 2, 3, 4: le classement reprends immédiatement après la valeur de l'égalité

# %% [markdown]
# Personnellement, je trouve DENSE_RANK plus intuitif <br /> et je n'ai encore jamais rencontré de cas de figure où j'ai eu besoin du RANK

# %% [markdown]
# <img src="images/rank_useless_staff_engineer_apple.png" />

# %% [markdown]
# ## Exercices

# %% [markdown]
# Obtenez le classement des salaires par sexe <br />
# (S'il y a une égalité pour la première place, <br />
# on souhaite que le 3ème ait le rang "2")

# %%
query = """
SELECT *,
DENSE_RANK() OVER(PARTITION BY sex ORDER BY wage DESC) AS index
FROM wages

"""
duckdb.sql(query).df()
# Out:
#             name    wage department sex  index
# 0        Kaouter  100000         IT   F      1
# 1        Zeinaba  100000         IT   F      1
# 2         Karima   95000         HR   F      2
# 3           Anna   85000      SALES   F      3
# 4         Sylvie   70000         IT   F      4
# 5          Diane   65000      SALES   F      5
# 6        Gregory  120000         IT   H      1
# 7       Benjamin  110000        CEO   H      2
# 8         Romain  100000         IT   H      3
# 9      Sebastien   90000         HR   H      4
# 10        Arthur   83000      SALES   H      5
# 11  Jean-Nicolas   75000         HR   H      6
# 12      François   68000         HR   H      7
# 13        Toufik   60000         IT   H      8
# 14        Daniel   55000      SALES   H      9

# %%
# %load solutions/17first_ranking_exercice.py
query = """
SELECT *,
DENSE_RANK() OVER(
    PARTITION BY sex 
    ORDER BY wage DESC) AS index
FROM wages
"""
duckdb.sql(query).df().head(13)
# Out:
#             name    wage department sex  index
# 0        Gregory  120000         IT   H      1
# 1       Benjamin  110000        CEO   H      2
# 2         Romain  100000         IT   H      3
# 3      Sebastien   90000         HR   H      4
# 4         Arthur   83000      SALES   H      5
# 5   Jean-Nicolas   75000         HR   H      6
# 6       François   68000         HR   H      7
# 7         Toufik   60000         IT   H      8
# 8         Daniel   55000      SALES   H      9
# 9        Kaouter  100000         IT   F      1
# 10       Zeinaba  100000         IT   F      1
# 11        Karima   95000         HR   F      2
# 12          Anna   85000      SALES   F      3

# %% [markdown]
# ### Cas pratique capteur retail

# %% [markdown]
# On souhaite savoir quelle entrée de l'hypermarché <br />
# est la plus fréquentée les Samedi

# %%
import random
random.seed(42)

# %%
df = pd.read_csv("data/capteur_a_retrail.csv")
df_porte_b = df.copy()
# On ajoute une porte_b
df_porte_b["capteur_id"] = "porte_b"
df_porte_b["visiteurs_count"] = df_porte_b["visiteurs_count"].apply(lambda x: round(x * (random.random() + 0.5), 0))
df = pd.concat([df, df_porte_b])
df.sample(7)
# Out:
#           date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 22  2023-08-26    porte_a           6000.0        7           4920.0
# 28  2023-09-02    porte_b           5390.0        7           4700.0
# 19  2023-08-23    porte_b           2786.0        4           4920.0
# 11  2023-08-14    porte_a           3900.0        2           4920.0
# 4   2023-08-05    porte_b           7419.0        7           4920.0
# 15  2023-08-18    porte_b           5225.0        6           4920.0
# 2   2023-08-03    porte_b           3410.0        5           4920.0
#
#     threshold_twenty_pct
# 22                3936.0
# 28                3760.0
# 19                3936.0
# 11                3936.0
# 4                 3936.0
# 15                3936.0
# 2                 3936.0

# %% [markdown]
# Exercice: faites une requête pour avoir la moyenne glissante des visiteurs <br />
# les Samedi, pour le capteur porte_a et le capteur porte_b

# %%
query = """
SELECT 
    *,
    AVG(visiteurs_count) OVER(PARTITION BY capteur_id ORDER BY date) AS avg_visitors_weekday
FROM df
WHERE weekday = 7

"""
duckdb.sql(query).df()
# Out:
#          date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0  2023-08-05    porte_a           6000.0        7           4920.0
# 1  2023-08-12    porte_a           6000.0        7           4920.0
# 2  2023-08-19    porte_a           5500.0        7           4920.0
# 3  2023-08-26    porte_a           6000.0        7           4920.0
# 4  2023-09-02    porte_a           4000.0        7           4700.0
# 5  2023-08-05    porte_b           7419.0        7           4920.0
# 6  2023-08-12    porte_b           4312.0        7           4920.0
# 7  2023-08-19    porte_b           3962.0        7           4920.0
# 8  2023-08-26    porte_b           5042.0        7           4920.0
# 9  2023-09-02    porte_b           5390.0        7           4700.0
#
#    threshold_twenty_pct  avg_visitors_weekday
# 0                3936.0           6000.000000
# 1                3936.0           6000.000000
# 2                3936.0           5833.333333
# 3                3936.0           5875.000000
# 4                3760.0           5500.000000
# 5                3936.0           7419.000000
# 6                3936.0           5865.500000
# 7                3936.0           5231.000000
# 8                3936.0           5183.750000
# 9                3760.0           5225.000000

# %%
# %load solutions/18avg_visitors_count_by_capteur_id.py
query = """
SELECT *,
AVG(visiteurs_count) OVER(
    PARTITION BY capteur_id 
    ORDER BY Date
    ) AS avg_visitors_weekday
FROM df
WHERE weekday = 7
ORDER BY capteur_id, date
"""
duckdb.sql(query).df()
# Out:
#          date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0  2023-08-05    porte_a           6000.0        7           4920.0
# 1  2023-08-12    porte_a           6000.0        7           4920.0
# 2  2023-08-19    porte_a           5500.0        7           4920.0
# 3  2023-08-26    porte_a           6000.0        7           4920.0
# 4  2023-09-02    porte_a           4000.0        7           4700.0
# 5  2023-08-05    porte_b           7419.0        7           4920.0
# 6  2023-08-12    porte_b           4312.0        7           4920.0
# 7  2023-08-19    porte_b           3962.0        7           4920.0
# 8  2023-08-26    porte_b           5042.0        7           4920.0
# 9  2023-09-02    porte_b           5390.0        7           4700.0
#
#    threshold_twenty_pct  avg_visitors_weekday
# 0                3936.0           6000.000000
# 1                3936.0           6000.000000
# 2                3936.0           5833.333333
# 3                3936.0           5875.000000
# 4                3760.0           5500.000000
# 5                3936.0           7419.000000
# 6                3936.0           5865.500000
# 7                3936.0           5231.000000
# 8                3936.0           5183.750000
# 9                3760.0           5225.000000

# %% [markdown]
# Attention, cette requête fonctionne parce que le fenêtrage se fait sur la donnée restante <b> après la clause WHERE </b>
#
# Si on enlève le WHERE weekday = 7, les calculs ne sont plus bons

# %%
# CETTE REQUETE N'EST PAS BONNE !!

query = """
SELECT *,
AVG(visiteurs_count) OVER(
    PARTITION BY capteur_id 
    ORDER BY Date
    ) AS avg_visitors_weekday
FROM df
ORDER BY capteur_id, weekday, date
"""
duckdb.sql(query).df().query("weekday == 7")
# Out:
#           date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 25  2023-08-05    porte_a           6000.0        7           4920.0
# 26  2023-08-12    porte_a           6000.0        7           4920.0
# 27  2023-08-19    porte_a           5500.0        7           4920.0
# 28  2023-08-26    porte_a           6000.0        7           4920.0
# 29  2023-09-02    porte_a           4000.0        7           4700.0
# 55  2023-08-05    porte_b           7419.0        7           4920.0
# 56  2023-08-12    porte_b           4312.0        7           4920.0
# 57  2023-08-19    porte_b           3962.0        7           4920.0
# 58  2023-08-26    porte_b           5042.0        7           4920.0
# 59  2023-09-02    porte_b           5390.0        7           4700.0
#
#     threshold_twenty_pct  avg_visitors_weekday
# 25                3936.0           5080.000000
# 26                3936.0           5045.454545
# 27                3936.0           4847.058824
# 28                3936.0           4939.130435
# 29                3760.0           4912.068966
# 55                3936.0           4475.200000
# 56                3936.0           4386.727273
# 57                3936.0           4176.352941
# 58                3936.0           4478.782609
# 59                3760.0           4443.862069

# %% [markdown]
# Pour avoir les bons résultats sur l'ensemble de la donnée, <br />
# il faut préciser davantage le fenêtrage en partitionnant par capteur_id ET par weekday:

# %%
query = """
SELECT
    *,
    AVG(visiteurs_count) OVER(PARTITION BY capteur_id, weekday ORDER BY DATE) AS avg_visitors_weekday
FROM df
ORDER BY capteur_id, weekday, date
"""
duckdb.sql(query).df()
# Out:
#           date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0   2023-08-07    porte_a           4200.0        2           4920.0
# 1   2023-08-14    porte_a           3900.0        2           4920.0
# 2   2023-08-21    porte_a           4300.0        2           4920.0
# 3   2023-08-28    porte_a           4300.0        2           4920.0
# 4   2023-09-04    porte_a           4500.0        2           4700.0
# 5   2023-08-01    porte_a           4200.0        3           4920.0
# 6   2023-08-08    porte_a           4700.0        3           4920.0
# 7   2023-08-15    porte_a           4200.0        3           4920.0
# 8   2023-08-22    porte_a           4900.0        3           4920.0
# 9   2023-08-29    porte_a           4750.0        3           4920.0
# 10  2023-08-02    porte_a           5300.0        4           4920.0
# 11  2023-08-09    porte_a           5300.0        4           4920.0
# 12  2023-08-16    porte_a           4700.0        4           4920.0
# 13  2023-08-23    porte_a           5500.0        4           4920.0
# 14  2023-08-30    porte_a           5500.0        4           4920.0
# 15  2023-08-03    porte_a           4400.0        5           4920.0
# 16  2023-08-10    porte_a           4400.0        5           4920.0
# 17  2023-08-17    porte_a           3600.0        5           4920.0
# 18  2023-08-24    porte_a           4700.0        5           4920.0
# 19  2023-08-31    porte_a           4700.0        5           4920.0
# 20  2023-08-04    porte_a           5500.0        6           4920.0
# 21  2023-08-11    porte_a           5500.0        6           4920.0
# 22  2023-08-18    porte_a           5000.0        6           4920.0
# 23  2023-08-25    porte_a           5800.0        6           4920.0
# 24  2023-09-01    porte_a           5600.0        6           4700.0
# 25  2023-08-05    porte_a           6000.0        7           4920.0
# 26  2023-08-12    porte_a           6000.0        7           4920.0
# 27  2023-08-19    porte_a           5500.0        7           4920.0
# 28  2023-08-26    porte_a           6000.0        7           4920.0
# 29  2023-09-02    porte_a           4000.0        7           4700.0
# 30  2023-08-07    porte_b           4942.0        2           4920.0
# 31  2023-08-14    porte_b           3921.0        2           4920.0
# 32  2023-08-21    porte_b           4684.0        2           4920.0
# 33  2023-08-28    porte_b           2819.0        2           4920.0
# 34  2023-09-04    porte_b           4967.0        2           4700.0
# 35  2023-08-01    porte_b           4786.0        3           4920.0
# 36  2023-08-08    porte_b           6543.0        3           4920.0
# 37  2023-08-15    porte_b           2211.0        3           4920.0
# 38  2023-08-22    porte_b           6416.0        3           4920.0
# 39  2023-08-29    porte_b           6922.0        3           4920.0
# 40  2023-08-02    porte_b           2783.0        4           4920.0
# 41  2023-08-09    porte_b           3111.0        4           4920.0
# 42  2023-08-16    porte_b           3285.0        4           4920.0
# 43  2023-08-23    porte_b           2786.0        4           4920.0
# 44  2023-08-30    porte_b           4601.0        4           4920.0
# 45  2023-08-03    porte_b           3410.0        5           4920.0
# 46  2023-08-10    porte_b           4056.0        5           4920.0
# 47  2023-08-17    porte_b           4140.0        5           4920.0
# 48  2023-08-24    porte_b           6137.0        5           4920.0
# 49  2023-08-31    porte_b           2786.0        5           4920.0
# 50  2023-08-04    porte_b           3978.0        6           4920.0
# 51  2023-08-11    porte_b           2914.0        6           4920.0
# 52  2023-08-18    porte_b           5225.0        6           4920.0
# 53  2023-08-25    porte_b           6949.0        6           4920.0
# 54  2023-09-01    porte_b           3342.0        6           4700.0
# 55  2023-08-05    porte_b           7419.0        7           4920.0
# 56  2023-08-12    porte_b           4312.0        7           4920.0
# 57  2023-08-19    porte_b           3962.0        7           4920.0
# 58  2023-08-26    porte_b           5042.0        7           4920.0
# 59  2023-09-02    porte_b           5390.0        7           4700.0
#
#     threshold_twenty_pct  avg_visitors_weekday
# 0                 3936.0           4200.000000
# 1                 3936.0           4050.000000
# 2                 3936.0           4133.333333
# 3                 3936.0           4175.000000
# 4                 3760.0           4240.000000
# 5                 3936.0           4200.000000
# 6                 3936.0           4450.000000
# 7                 3936.0           4366.666667
# 8                 3936.0           4500.000000
# 9                 3936.0           4550.000000
# 10                3936.0           5300.000000
# 11                3936.0           5300.000000
# 12                3936.0           5100.000000
# 13                3936.0           5200.000000
# 14                3936.0           5260.000000
# 15                3936.0           4400.000000
# 16                3936.0           4400.000000
# 17                3936.0           4133.333333
# 18                3936.0           4275.000000
# 19                3936.0           4360.000000
# 20                3936.0           5500.000000
# 21                3936.0           5500.000000
# 22                3936.0           5333.333333
# 23                3936.0           5450.000000
# 24                3760.0           5480.000000
# 25                3936.0           6000.000000
# 26                3936.0           6000.000000
# 27                3936.0           5833.333333
# 28                3936.0           5875.000000
# 29                3760.0           5500.000000
# 30                3936.0           4942.000000
# 31                3936.0           4431.500000
# 32                3936.0           4515.666667
# 33                3936.0           4091.500000
# 34                3760.0           4266.600000
# 35                3936.0           4786.000000
# 36                3936.0           5664.500000
# 37                3936.0           4513.333333
# 38                3936.0           4989.000000
# 39                3936.0           5375.600000
# 40                3936.0           2783.000000
# 41                3936.0           2947.000000
# 42                3936.0           3059.666667
# 43                3936.0           2991.250000
# 44                3936.0           3313.200000
# 45                3936.0           3410.000000
# 46                3936.0           3733.000000
# 47                3936.0           3868.666667
# 48                3936.0           4435.750000
# 49                3936.0           4105.800000
# 50                3936.0           3978.000000
# 51                3936.0           3446.000000
# 52                3936.0           4039.000000
# 53                3936.0           4766.500000
# 54                3760.0           4481.600000
# 55                3936.0           7419.000000
# 56                3936.0           5865.500000
# 57                3936.0           5231.000000
# 58                3936.0           5183.750000
# 59                3760.0           5225.000000

# %%
# %load solutions/19correct_avg_visitors_count_by_capteur_id.py
query = """
SELECT *,
AVG(visiteurs_count) OVER(
    PARTITION BY capteur_id, weekday
    ORDER BY Date
    ) AS avg_visitors_weekday
FROM df
ORDER BY capteur_id, weekday, date
"""
duckdb.sql(query).df().query("weekday == 7")
# Out:
#           date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 25  2023-08-05    porte_a           6000.0        7           4920.0
# 26  2023-08-12    porte_a           6000.0        7           4920.0
# 27  2023-08-19    porte_a           5500.0        7           4920.0
# 28  2023-08-26    porte_a           6000.0        7           4920.0
# 29  2023-09-02    porte_a           4000.0        7           4700.0
# 55  2023-08-05    porte_b           7419.0        7           4920.0
# 56  2023-08-12    porte_b           4312.0        7           4920.0
# 57  2023-08-19    porte_b           3962.0        7           4920.0
# 58  2023-08-26    porte_b           5042.0        7           4920.0
# 59  2023-09-02    porte_b           5390.0        7           4700.0
#
#     threshold_twenty_pct  avg_visitors_weekday
# 25                3936.0           6000.000000
# 26                3936.0           6000.000000
# 27                3936.0           5833.333333
# 28                3936.0           5875.000000
# 29                3760.0           5500.000000
# 55                3936.0           7419.000000
# 56                3936.0           5865.500000
# 57                3936.0           5231.000000
# 58                3936.0           5183.750000
# 59                3760.0           5225.000000

# %% [markdown]
# Utilisez cette requête pour obtenir, chaque semaine, le classement entre les capteurs_a et _b <br />
# (Hint: utilisez une CTE)

# %%
query = """
WITH moving_avg_visitors AS (
SELECT
    *,
    AVG(visiteurs_count) OVER(
        PARTITION BY capteur_id, weekday ORDER BY date) AS avg_visitors_weekday
FROM df
ORDER BY capteur_id, weekday
)

SELECT
    *,
    DENSE_RANK() OVER(PARTITION BY date ORDER BY avg_visitors_weekday DESC) AS updated_ranking
FROM moving_avg_visitors
ORDER BY updated_ranking, date

"""
duckdb.sql(query).df()
# Out:
#           date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0   2023-08-01    porte_b           4786.0        3           4920.0
# 1   2023-08-02    porte_a           5300.0        4           4920.0
# 2   2023-08-03    porte_a           4400.0        5           4920.0
# 3   2023-08-04    porte_a           5500.0        6           4920.0
# 4   2023-08-05    porte_b           7419.0        7           4920.0
# 5   2023-08-07    porte_b           4942.0        2           4920.0
# 6   2023-08-08    porte_b           6543.0        3           4920.0
# 7   2023-08-09    porte_a           5300.0        4           4920.0
# 8   2023-08-10    porte_a           4400.0        5           4920.0
# 9   2023-08-11    porte_a           5500.0        6           4920.0
# 10  2023-08-12    porte_a           6000.0        7           4920.0
# 11  2023-08-14    porte_b           3921.0        2           4920.0
# 12  2023-08-15    porte_b           2211.0        3           4920.0
# 13  2023-08-16    porte_a           4700.0        4           4920.0
# 14  2023-08-17    porte_a           3600.0        5           4920.0
# 15  2023-08-18    porte_a           5000.0        6           4920.0
# 16  2023-08-19    porte_a           5500.0        7           4920.0
# 17  2023-08-21    porte_b           4684.0        2           4920.0
# 18  2023-08-22    porte_b           6416.0        3           4920.0
# 19  2023-08-23    porte_a           5500.0        4           4920.0
# 20  2023-08-24    porte_b           6137.0        5           4920.0
# 21  2023-08-25    porte_a           5800.0        6           4920.0
# 22  2023-08-26    porte_a           6000.0        7           4920.0
# 23  2023-08-28    porte_a           4300.0        2           4920.0
# 24  2023-08-29    porte_b           6922.0        3           4920.0
# 25  2023-08-30    porte_a           5500.0        4           4920.0
# 26  2023-08-31    porte_a           4700.0        5           4920.0
# 27  2023-09-01    porte_a           5600.0        6           4700.0
# 28  2023-09-02    porte_a           4000.0        7           4700.0
# 29  2023-09-04    porte_b           4967.0        2           4700.0
# 30  2023-08-01    porte_a           4200.0        3           4920.0
# 31  2023-08-02    porte_b           2783.0        4           4920.0
# 32  2023-08-03    porte_b           3410.0        5           4920.0
# 33  2023-08-04    porte_b           3978.0        6           4920.0
# 34  2023-08-05    porte_a           6000.0        7           4920.0
# 35  2023-08-07    porte_a           4200.0        2           4920.0
# 36  2023-08-08    porte_a           4700.0        3           4920.0
# 37  2023-08-09    porte_b           3111.0        4           4920.0
# 38  2023-08-10    porte_b           4056.0        5           4920.0
# 39  2023-08-11    porte_b           2914.0        6           4920.0
# 40  2023-08-12    porte_b           4312.0        7           4920.0
# 41  2023-08-14    porte_a           3900.0        2           4920.0
# 42  2023-08-15    porte_a           4200.0        3           4920.0
# 43  2023-08-16    porte_b           3285.0        4           4920.0
# 44  2023-08-17    porte_b           4140.0        5           4920.0
# 45  2023-08-18    porte_b           5225.0        6           4920.0
# 46  2023-08-19    porte_b           3962.0        7           4920.0
# 47  2023-08-21    porte_a           4300.0        2           4920.0
# 48  2023-08-22    porte_a           4900.0        3           4920.0
# 49  2023-08-23    porte_b           2786.0        4           4920.0
# 50  2023-08-24    porte_a           4700.0        5           4920.0
# 51  2023-08-25    porte_b           6949.0        6           4920.0
# 52  2023-08-26    porte_b           5042.0        7           4920.0
# 53  2023-08-28    porte_b           2819.0        2           4920.0
# 54  2023-08-29    porte_a           4750.0        3           4920.0
# 55  2023-08-30    porte_b           4601.0        4           4920.0
# 56  2023-08-31    porte_b           2786.0        5           4920.0
# 57  2023-09-01    porte_b           3342.0        6           4700.0
# 58  2023-09-02    porte_b           5390.0        7           4700.0
# 59  2023-09-04    porte_a           4500.0        2           4700.0
#
#     threshold_twenty_pct  avg_visitors_weekday  updated_ranking
# 0                 3936.0           4786.000000                1
# 1                 3936.0           5300.000000                1
# 2                 3936.0           4400.000000                1
# 3                 3936.0           5500.000000                1
# 4                 3936.0           7419.000000                1
# 5                 3936.0           4942.000000                1
# 6                 3936.0           5664.500000                1
# 7                 3936.0           5300.000000                1
# 8                 3936.0           4400.000000                1
# 9                 3936.0           5500.000000                1
# 10                3936.0           6000.000000                1
# 11                3936.0           4431.500000                1
# 12                3936.0           4513.333333                1
# 13                3936.0           5100.000000                1
# 14                3936.0           4133.333333                1
# 15                3936.0           5333.333333                1
# 16                3936.0           5833.333333                1
# 17                3936.0           4515.666667                1
# 18                3936.0           4989.000000                1
# 19                3936.0           5200.000000                1
# 20                3936.0           4435.750000                1
# 21                3936.0           5450.000000                1
# 22                3936.0           5875.000000                1
# 23                3936.0           4175.000000                1
# 24                3936.0           5375.600000                1
# 25                3936.0           5260.000000                1
# 26                3936.0           4360.000000                1
# 27                3760.0           5480.000000                1
# 28                3760.0           5500.000000                1
# 29                3760.0           4266.600000                1
# 30                3936.0           4200.000000                2
# 31                3936.0           2783.000000                2
# 32                3936.0           3410.000000                2
# 33                3936.0           3978.000000                2
# 34                3936.0           6000.000000                2
# 35                3936.0           4200.000000                2
# 36                3936.0           4450.000000                2
# 37                3936.0           2947.000000                2
# 38                3936.0           3733.000000                2
# 39                3936.0           3446.000000                2
# 40                3936.0           5865.500000                2
# 41                3936.0           4050.000000                2
# 42                3936.0           4366.666667                2
# 43                3936.0           3059.666667                2
# 44                3936.0           3868.666667                2
# 45                3936.0           4039.000000                2
# 46                3936.0           5231.000000                2
# 47                3936.0           4133.333333                2
# 48                3936.0           4500.000000                2
# 49                3936.0           2991.250000                2
# 50                3936.0           4275.000000                2
# 51                3936.0           4766.500000                2
# 52                3936.0           5183.750000                2
# 53                3936.0           4091.500000                2
# 54                3936.0           4550.000000                2
# 55                3936.0           3313.200000                2
# 56                3936.0           4105.800000                2
# 57                3760.0           4481.600000                2
# 58                3760.0           5225.000000                2
# 59                3760.0           4240.000000                2

# %%
# %load solutions/20updated_ranking.py
query = """
WITH moving_avg_visitors AS (
    SELECT *,
    AVG(visiteurs_count) OVER(
        PARTITION BY capteur_id, weekday
        ORDER BY Date
        ) AS avg_visitors_weekday,
    FROM df
    ORDER BY capteur_id, weekday, date
)

SELECT * , 
DENSE_RANK() OVER(
    PARTITION BY date
    ORDER BY avg_visitors_weekday DESC
) AS updated_ranking 
FROM 
moving_avg_visitors
ORDER BY updated_ranking, date
"""
duckdb.sql(query).df().query("weekday == 7")
# Out:
#           date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 4   2023-08-05    porte_b           7419.0        7           4920.0
# 10  2023-08-12    porte_a           6000.0        7           4920.0
# 16  2023-08-19    porte_a           5500.0        7           4920.0
# 22  2023-08-26    porte_a           6000.0        7           4920.0
# 28  2023-09-02    porte_a           4000.0        7           4700.0
# 34  2023-08-05    porte_a           6000.0        7           4920.0
# 40  2023-08-12    porte_b           4312.0        7           4920.0
# 46  2023-08-19    porte_b           3962.0        7           4920.0
# 52  2023-08-26    porte_b           5042.0        7           4920.0
# 58  2023-09-02    porte_b           5390.0        7           4700.0
#
#     threshold_twenty_pct  avg_visitors_weekday  updated_ranking
# 4                 3936.0           7419.000000                1
# 10                3936.0           6000.000000                1
# 16                3936.0           5833.333333                1
# 22                3936.0           5875.000000                1
# 28                3760.0           5500.000000                1
# 34                3936.0           6000.000000                2
# 40                3936.0           5865.500000                2
# 46                3936.0           5231.000000                2
# 52                3936.0           5183.750000                2
# 58                3760.0           5225.000000                2
