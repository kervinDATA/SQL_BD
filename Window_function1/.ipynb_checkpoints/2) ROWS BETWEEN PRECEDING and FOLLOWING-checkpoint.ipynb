# %%
import pandas as pd
import random
from datetime import datetime, timedelta
import duckdb

random.seed(42)

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %% [markdown]
# ## Rappel

# %% [markdown]
# Avec la clause OVER(), on a vu qu'on pouvait calculer <br />
# une agrégation sur l'ensemble des lignes de la table

# %% [markdown]
# Puis on a vu que OVER(ORDER BY col) permet d'avoir <br />
# une agrégation de toutes les lignes précédentes jusqu'à la ligne en cours

# %% [markdown]
# Comment faire si on veut limiter le nombre de lignes précédentes <br /> prises en compte dans le calcul ?

# %%
start_date = datetime(2023, 9, 1)
end_date = datetime(2023, 9, 30)
date_range = [start_date + timedelta(days=x) for x in range((end_date - start_date).days + 1)]

sales_data = [random.randint(1, 7) * 1000 for _ in range(len(date_range))]

df = pd.DataFrame({"date": date_range, "daily_sales": sales_data})

df.head()
# Out:
#         date  daily_sales
# 0 2023-09-01         6000
# 1 2023-09-02         1000
# 2 2023-09-03         1000
# 3 2023-09-04         6000
# 4 2023-09-05         3000

# %% [markdown]
# Rappel: somme et moyenne progressives sur toute la donnée:

# %%
query = """
SELECT date, daily_sales,
SUM(daily_sales) OVER(ORDER BY date) as running_total,
COUNT(daily_sales) OVER(ORDER BY date) as running_count,
AVG(daily_sales) OVER(ORDER BY date) as running_mean,
from df
"""
duckdb.sql(query).df().head(10)
# Out:
#         date  daily_sales  running_total  running_count  running_mean
# 0 2023-09-01         6000         6000.0              1   6000.000000
# 1 2023-09-02         1000         7000.0              2   3500.000000
# 2 2023-09-03         1000         8000.0              3   2666.666667
# 3 2023-09-04         6000        14000.0              4   3500.000000
# 4 2023-09-05         3000        17000.0              5   3400.000000
# 5 2023-09-06         2000        19000.0              6   3166.666667
# 6 2023-09-07         2000        21000.0              7   3000.000000
# 7 2023-09-08         2000        23000.0              8   2875.000000
# 8 2023-09-09         6000        29000.0              9   3222.222222
# 9 2023-09-10         1000        30000.0             10   3000.000000

# %% [markdown]
# Rappel: le P.O. estime qu'il n'est pas nécessaire <br />
# de garder les anciennes valeurs au delà d'une semaine.
#
# Il veut un "moving average" uniquement sur les 7 derniers jours.

# %% [markdown]
# ### La syntaxe ROWS BETWEEN

# %%
query = """
SELECT date, daily_sales,
SUM(daily_sales) OVER(
    ORDER BY date 
    ROWS BETWEEN 2 PRECEDING and CURRENT ROW
    ) AS moving_total_three_last_rows,
SUM(daily_sales) OVER(
    ORDER BY date
    ) AS moving_total,
from df
"""
duckdb.sql(query).df().head(7)
# Out:
#         date  daily_sales  moving_total_three_last_rows  moving_total
# 0 2023-09-01         6000                        6000.0        6000.0
# 1 2023-09-02         1000                        7000.0        7000.0
# 2 2023-09-03         1000                        8000.0        8000.0
# 3 2023-09-04         6000                        8000.0       14000.0
# 4 2023-09-05         3000                       10000.0       17000.0
# 5 2023-09-06         2000                       11000.0       19000.0
# 6 2023-09-07         2000                        7000.0       21000.0

# %% [markdown]
# Exercice: faites la même chose avec la moyenne  <br />
# (pas de C/C => tapez l'instruction pour mieux mémoriser la syntaxe)

# %%
query = """
SELECT
    *,
    AVG(daily_sales) OVER(ORDER BY date ROWS BETWEEN 2 PRECEDING and CURRENT ROW) AS moving_average_last_3_months,
    AVG(daily_sales) OVER(ORDER BY date) AS moving_average
FROM df

"""
duckdb.sql(query).df()
# Out:
#          date  daily_sales  moving_average_last_3_months  moving_average
# 0  2023-09-01         6000                   6000.000000     6000.000000
# 1  2023-09-02         1000                   3500.000000     3500.000000
# 2  2023-09-03         1000                   2666.666667     2666.666667
# 3  2023-09-04         6000                   2666.666667     3500.000000
# 4  2023-09-05         3000                   3333.333333     3400.000000
# 5  2023-09-06         2000                   3666.666667     3166.666667
# 6  2023-09-07         2000                   2333.333333     3000.000000
# 7  2023-09-08         2000                   2000.000000     2875.000000
# 8  2023-09-09         6000                   3333.333333     3222.222222
# 9  2023-09-10         1000                   3000.000000     3000.000000
# 10 2023-09-11         6000                   4333.333333     3272.727273
# 11 2023-09-12         6000                   4333.333333     3500.000000
# 12 2023-09-13         5000                   5666.666667     3615.384615
# 13 2023-09-14         1000                   4000.000000     3428.571429
# 14 2023-09-15         5000                   3666.666667     3533.333333
# 15 2023-09-16         4000                   3333.333333     3562.500000
# 16 2023-09-17         1000                   3333.333333     3411.764706
# 17 2023-09-18         1000                   2000.000000     3277.777778
# 18 2023-09-19         1000                   1000.000000     3157.894737
# 19 2023-09-20         2000                   1333.333333     3100.000000
# 20 2023-09-21         2000                   1666.666667     3047.619048
# 21 2023-09-22         5000                   3000.000000     3136.363636
# 22 2023-09-23         5000                   4000.000000     3217.391304
# 23 2023-09-24         1000                   3666.666667     3125.000000
# 24 2023-09-25         5000                   3666.666667     3200.000000
# 25 2023-09-26         2000                   2666.666667     3153.846154
# 26 2023-09-27         6000                   4333.333333     3259.259259
# 27 2023-09-28         6000                   4666.666667     3357.142857
# 28 2023-09-29         6000                   6000.000000     3448.275862
# 29 2023-09-30         5000                   5666.666667     3500.000000

# %% [markdown]
# ## Fenêtre avant après

# %%
query = """
SELECT date, daily_sales,
SUM(daily_sales) OVER(
    ORDER BY date 
    ROWS BETWEEN 1 PRECEDING and 1 FOLLOWING
    ) AS moving_total,
AVG(daily_sales) OVER(
    ORDER BY date 
    ROWS BETWEEN 1 PRECEDING and 1 FOLLOWING)
    AS moving_average,
from df
"""
duckdb.sql(query).df().head(7)
# Out:
#         date  daily_sales  moving_total  moving_average
# 0 2023-09-01         6000        7000.0     3500.000000
# 1 2023-09-02         1000        8000.0     2666.666667
# 2 2023-09-03         1000        8000.0     2666.666667
# 3 2023-09-04         6000       10000.0     3333.333333
# 4 2023-09-05         3000       11000.0     3666.666667
# 5 2023-09-06         2000        7000.0     2333.333333
# 6 2023-09-07         2000        6000.0     2000.000000

# %% [markdown]
# Exercice: <br />
# Faites un moving average avec une fenêtre de cinq lignes <br />
# deux avant, la ligne en cours, et deux lignes après

# %%
query = """
SELECT 
    *,
    AVG(daily_sales) OVER(ORDER BY date ROWS BETWEEN 2 PRECEDING and 2 FOLLOWING) AS moving_avg_2before_2after,
    AVG(daily_sales) OVER(ORDER BY date) AS moving_avg
FROM df

"""
duckdb.sql(query).df()
# Out:
#          date  daily_sales  moving_avg_2before_2after   moving_avg
# 0  2023-09-01         6000                2666.666667  6000.000000
# 1  2023-09-02         1000                3500.000000  3500.000000
# 2  2023-09-03         1000                3400.000000  2666.666667
# 3  2023-09-04         6000                2600.000000  3500.000000
# 4  2023-09-05         3000                2800.000000  3400.000000
# 5  2023-09-06         2000                3000.000000  3166.666667
# 6  2023-09-07         2000                3000.000000  3000.000000
# 7  2023-09-08         2000                2600.000000  2875.000000
# 8  2023-09-09         6000                3400.000000  3222.222222
# 9  2023-09-10         1000                4200.000000  3000.000000
# 10 2023-09-11         6000                4800.000000  3272.727273
# 11 2023-09-12         6000                3800.000000  3500.000000
# 12 2023-09-13         5000                4600.000000  3615.384615
# 13 2023-09-14         1000                4200.000000  3428.571429
# 14 2023-09-15         5000                3200.000000  3533.333333
# 15 2023-09-16         4000                2400.000000  3562.500000
# 16 2023-09-17         1000                2400.000000  3411.764706
# 17 2023-09-18         1000                1800.000000  3277.777778
# 18 2023-09-19         1000                1400.000000  3157.894737
# 19 2023-09-20         2000                2200.000000  3100.000000
# 20 2023-09-21         2000                3000.000000  3047.619048
# 21 2023-09-22         5000                3000.000000  3136.363636
# 22 2023-09-23         5000                3600.000000  3217.391304
# 23 2023-09-24         1000                3600.000000  3125.000000
# 24 2023-09-25         5000                3800.000000  3200.000000
# 25 2023-09-26         2000                4000.000000  3153.846154
# 26 2023-09-27         6000                5000.000000  3259.259259
# 27 2023-09-28         6000                5000.000000  3357.142857
# 28 2023-09-29         6000                5750.000000  3448.275862
# 29 2023-09-30         5000                5666.666667  3500.000000

# %%
# %load solutions/5moving_average_2before_2after.py
query = """
SELECT date, daily_sales,
AVG(daily_sales) OVER(
    ORDER BY date 
    ROWS BETWEEN 2 PRECEDING and 2 FOLLOWING)
    AS moving_average,
from df
"""
duckdb.sql(query).df().head(7)
# Out:
#         date  daily_sales  moving_average
# 0 2023-09-01         6000     2666.666667
# 1 2023-09-02         1000     3500.000000
# 2 2023-09-03         1000     3400.000000
# 3 2023-09-04         6000     2600.000000
# 4 2023-09-05         3000     2800.000000
# 5 2023-09-06         2000     3000.000000
# 6 2023-09-07         2000     3000.000000

# %% [markdown]
# ## Exercices

# %%
capteurs = pd.read_csv("data/capteur_a_retrail.csv")
capteurs.head(8)
# Out:
#          date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0  2023-08-01    porte_a           4200.0        3           4920.0
# 1  2023-08-02    porte_a           5300.0        4           4920.0
# 2  2023-08-03    porte_a           4400.0        5           4920.0
# 3  2023-08-04    porte_a           5500.0        6           4920.0
# 4  2023-08-05    porte_a           6000.0        7           4920.0
# 5  2023-08-07    porte_a           4200.0        2           4920.0
# 6  2023-08-08    porte_a           4700.0        3           4920.0
# 7  2023-08-09    porte_a           5300.0        4           4920.0
#
#    threshold_twenty_pct
# 0                3936.0
# 1                3936.0
# 2                3936.0
# 3                3936.0
# 4                3936.0
# 5                3936.0
# 6                3936.0
# 7                3936.0

# %% [markdown]
# ### A) Faire la moyenne mobile sur les 7 derniers jours

# %%
query = """
SELECT
    *,
    AVG(visiteurs_count) OVER(ORDER BY date ROWS BETWEEN 6 PRECEDING and CURRENT ROW) AS seven_daysmoving_AVG
FROM capteurs

"""
duckdb.sql(query).df()
# Out:
#           date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0   2023-08-01    porte_a           4200.0        3           4920.0
# 1   2023-08-02    porte_a           5300.0        4           4920.0
# 2   2023-08-03    porte_a           4400.0        5           4920.0
# 3   2023-08-04    porte_a           5500.0        6           4920.0
# 4   2023-08-05    porte_a           6000.0        7           4920.0
# 5   2023-08-07    porte_a           4200.0        2           4920.0
# 6   2023-08-08    porte_a           4700.0        3           4920.0
# 7   2023-08-09    porte_a           5300.0        4           4920.0
# 8   2023-08-10    porte_a           4400.0        5           4920.0
# 9   2023-08-11    porte_a           5500.0        6           4920.0
# 10  2023-08-12    porte_a           6000.0        7           4920.0
# 11  2023-08-14    porte_a           3900.0        2           4920.0
# 12  2023-08-15    porte_a           4200.0        3           4920.0
# 13  2023-08-16    porte_a           4700.0        4           4920.0
# 14  2023-08-17    porte_a           3600.0        5           4920.0
# 15  2023-08-18    porte_a           5000.0        6           4920.0
# 16  2023-08-19    porte_a           5500.0        7           4920.0
# 17  2023-08-21    porte_a           4300.0        2           4920.0
# 18  2023-08-22    porte_a           4900.0        3           4920.0
# 19  2023-08-23    porte_a           5500.0        4           4920.0
# 20  2023-08-24    porte_a           4700.0        5           4920.0
# 21  2023-08-25    porte_a           5800.0        6           4920.0
# 22  2023-08-26    porte_a           6000.0        7           4920.0
# 23  2023-08-28    porte_a           4300.0        2           4920.0
# 24  2023-08-29    porte_a           4750.0        3           4920.0
# 25  2023-08-30    porte_a           5500.0        4           4920.0
# 26  2023-08-31    porte_a           4700.0        5           4920.0
# 27  2023-09-01    porte_a           5600.0        6           4700.0
# 28  2023-09-02    porte_a           4000.0        7           4700.0
# 29  2023-09-04    porte_a           4500.0        2           4700.0
#
#     threshold_twenty_pct  seven_daysmoving_AVG
# 0                 3936.0           4200.000000
# 1                 3936.0           4750.000000
# 2                 3936.0           4633.333333
# 3                 3936.0           4850.000000
# 4                 3936.0           5080.000000
# 5                 3936.0           4933.333333
# 6                 3936.0           4900.000000
# 7                 3936.0           5057.142857
# 8                 3936.0           4928.571429
# 9                 3936.0           5085.714286
# 10                3936.0           5157.142857
# 11                3936.0           4857.142857
# 12                3936.0           4857.142857
# 13                3936.0           4857.142857
# 14                3936.0           4614.285714
# 15                3936.0           4700.000000
# 16                3936.0           4700.000000
# 17                3936.0           4457.142857
# 18                3936.0           4600.000000
# 19                3936.0           4785.714286
# 20                3936.0           4785.714286
# 21                3936.0           5100.000000
# 22                3936.0           5242.857143
# 23                3936.0           5071.428571
# 24                3936.0           5135.714286
# 25                3936.0           5221.428571
# 26                3936.0           5107.142857
# 27                3760.0           5235.714286
# 28                3760.0           4978.571429
# 29                3760.0           4764.285714

# %%
# %load solutions/6moving_average_capteurs_last_seven_days.py
query = """
SELECT *,
AVG(visiteurs_count) OVER(
    ORDER BY DATE 
    ROWS BETWEEN 6 PRECEDING AND CURRENT ROW
) AS seven_daysmoving_average
FROM capteurs
"""
duckdb.sql(query).df().head(10)
# Out:
#          date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0  2023-08-01    porte_a           4200.0        3           4920.0
# 1  2023-08-02    porte_a           5300.0        4           4920.0
# 2  2023-08-03    porte_a           4400.0        5           4920.0
# 3  2023-08-04    porte_a           5500.0        6           4920.0
# 4  2023-08-05    porte_a           6000.0        7           4920.0
# 5  2023-08-07    porte_a           4200.0        2           4920.0
# 6  2023-08-08    porte_a           4700.0        3           4920.0
# 7  2023-08-09    porte_a           5300.0        4           4920.0
# 8  2023-08-10    porte_a           4400.0        5           4920.0
# 9  2023-08-11    porte_a           5500.0        6           4920.0
#
#    threshold_twenty_pct  seven_daysmoving_average
# 0                3936.0               4200.000000
# 1                3936.0               4750.000000
# 2                3936.0               4633.333333
# 3                3936.0               4850.000000
# 4                3936.0               5080.000000
# 5                3936.0               4933.333333
# 6                3936.0               4900.000000
# 7                3936.0               5057.142857
# 8                3936.0               4928.571429
# 9                3936.0               5085.714286

# %% [markdown]
# ### B) Vérification de cette moyenne mobile

# %% [markdown]
# Ajouter le running total sur les sept derniers jours <br />
# le count(*) sur les sept derniers jours <br />
# la division de ce running_total par le count <br />
# pour comparer avec la moyenne précédemment obtenue

# %%
query = """
SELECT
    *,
    SUM(visiteurs_count) OVER(ORDER BY date ROWS BETWEEN 6 PRECEDING and CURRENT ROW) AS seven_days_running_total,
    COUNT(*) OVER(ORDER BY date ROWS BETWEEN 6 PRECEDING and CURRENT ROW) AS seven_days_moving_count,
    
    SUM(visiteurs_count) OVER(ORDER BY date ROWS BETWEEN 6 PRECEDING and CURRENT ROW) /
    COUNT(*) OVER(ORDER BY date ROWS BETWEEN 6 PRECEDING and CURRENT ROW) AS verif,
    
    AVG(visiteurs_count) OVER(ORDER BY date ROWS BETWEEN 6 PRECEDING and CURRENT ROW) AS seven_daysmoving_AVG
    
FROM capteurs

"""
duckdb.sql(query).df()
# Out:
#           date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0   2023-08-01    porte_a           4200.0        3           4920.0
# 1   2023-08-02    porte_a           5300.0        4           4920.0
# 2   2023-08-03    porte_a           4400.0        5           4920.0
# 3   2023-08-04    porte_a           5500.0        6           4920.0
# 4   2023-08-05    porte_a           6000.0        7           4920.0
# 5   2023-08-07    porte_a           4200.0        2           4920.0
# 6   2023-08-08    porte_a           4700.0        3           4920.0
# 7   2023-08-09    porte_a           5300.0        4           4920.0
# 8   2023-08-10    porte_a           4400.0        5           4920.0
# 9   2023-08-11    porte_a           5500.0        6           4920.0
# 10  2023-08-12    porte_a           6000.0        7           4920.0
# 11  2023-08-14    porte_a           3900.0        2           4920.0
# 12  2023-08-15    porte_a           4200.0        3           4920.0
# 13  2023-08-16    porte_a           4700.0        4           4920.0
# 14  2023-08-17    porte_a           3600.0        5           4920.0
# 15  2023-08-18    porte_a           5000.0        6           4920.0
# 16  2023-08-19    porte_a           5500.0        7           4920.0
# 17  2023-08-21    porte_a           4300.0        2           4920.0
# 18  2023-08-22    porte_a           4900.0        3           4920.0
# 19  2023-08-23    porte_a           5500.0        4           4920.0
# 20  2023-08-24    porte_a           4700.0        5           4920.0
# 21  2023-08-25    porte_a           5800.0        6           4920.0
# 22  2023-08-26    porte_a           6000.0        7           4920.0
# 23  2023-08-28    porte_a           4300.0        2           4920.0
# 24  2023-08-29    porte_a           4750.0        3           4920.0
# 25  2023-08-30    porte_a           5500.0        4           4920.0
# 26  2023-08-31    porte_a           4700.0        5           4920.0
# 27  2023-09-01    porte_a           5600.0        6           4700.0
# 28  2023-09-02    porte_a           4000.0        7           4700.0
# 29  2023-09-04    porte_a           4500.0        2           4700.0
#
#     threshold_twenty_pct  seven_days_running_total  seven_days_moving_count  \
# 0                 3936.0                    4200.0                        1
# 1                 3936.0                    9500.0                        2
# 2                 3936.0                   13900.0                        3
# 3                 3936.0                   19400.0                        4
# 4                 3936.0                   25400.0                        5
# 5                 3936.0                   29600.0                        6
# 6                 3936.0                   34300.0                        7
# 7                 3936.0                   35400.0                        7
# 8                 3936.0                   34500.0                        7
# 9                 3936.0                   35600.0                        7
# 10                3936.0                   36100.0                        7
# 11                3936.0                   34000.0                        7
# 12                3936.0                   34000.0                        7
# 13                3936.0                   34000.0                        7
# 14                3936.0                   32300.0                        7
# 15                3936.0                   32900.0                        7
# 16                3936.0                   32900.0                        7
# 17                3936.0                   31200.0                        7
# 18                3936.0                   32200.0                        7
# 19                3936.0                   33500.0                        7
# 20                3936.0                   33500.0                        7
# 21                3936.0                   35700.0                        7
# 22                3936.0                   36700.0                        7
# 23                3936.0                   35500.0                        7
# 24                3936.0                   35950.0                        7
# 25                3936.0                   36550.0                        7
# 26                3936.0                   35750.0                        7
# 27                3760.0                   36650.0                        7
# 28                3760.0                   34850.0                        7
# 29                3760.0                   33350.0                        7
#
#           verif  seven_daysmoving_AVG
# 0   4200.000000           4200.000000
# 1   4750.000000           4750.000000
# 2   4633.333333           4633.333333
# 3   4850.000000           4850.000000
# 4   5080.000000           5080.000000
# 5   4933.333333           4933.333333
# 6   4900.000000           4900.000000
# 7   5057.142857           5057.142857
# 8   4928.571429           4928.571429
# 9   5085.714286           5085.714286
# 10  5157.142857           5157.142857
# 11  4857.142857           4857.142857
# 12  4857.142857           4857.142857
# 13  4857.142857           4857.142857
# 14  4614.285714           4614.285714
# 15  4700.000000           4700.000000
# 16  4700.000000           4700.000000
# 17  4457.142857           4457.142857
# 18  4600.000000           4600.000000
# 19  4785.714286           4785.714286
# 20  4785.714286           4785.714286
# 21  5100.000000           5100.000000
# 22  5242.857143           5242.857143
# 23  5071.428571           5071.428571
# 24  5135.714286           5135.714286
# 25  5221.428571           5221.428571
# 26  5107.142857           5107.142857
# 27  5235.714286           5235.714286
# 28  4978.571429           4978.571429
# 29  4764.285714           4764.285714

# %%
# %load solutions/7verification_calculs.py
query = """
SELECT *,
SUM(visiteurs_count) OVER(
    ORDER BY DATE 
    ROWS BETWEEN 6 PRECEDING AND CURRENT ROW
    ) AS seven_days_running_total,
COUNT(*) OVER(
    ORDER BY DATE 
    ROWS BETWEEN 6 PRECEDING AND CURRENT ROW
    ) AS seven_days_moving_count,
seven_days_running_total / seven_days_moving_count AS verif,
AVG(visiteurs_count) OVER(
    ORDER BY DATE 
    ROWS BETWEEN 6 PRECEDING AND CURRENT ROW
    ) AS seven_days_moving_average
FROM capteurs
"""
duckdb.sql(query).df().head(10)
# Out:
#          date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0  2023-08-01    porte_a           4200.0        3           4920.0
# 1  2023-08-02    porte_a           5300.0        4           4920.0
# 2  2023-08-03    porte_a           4400.0        5           4920.0
# 3  2023-08-04    porte_a           5500.0        6           4920.0
# 4  2023-08-05    porte_a           6000.0        7           4920.0
# 5  2023-08-07    porte_a           4200.0        2           4920.0
# 6  2023-08-08    porte_a           4700.0        3           4920.0
# 7  2023-08-09    porte_a           5300.0        4           4920.0
# 8  2023-08-10    porte_a           4400.0        5           4920.0
# 9  2023-08-11    porte_a           5500.0        6           4920.0
#
#    threshold_twenty_pct  seven_days_running_total  seven_days_moving_count  \
# 0                3936.0                    4200.0                        1
# 1                3936.0                    9500.0                        2
# 2                3936.0                   13900.0                        3
# 3                3936.0                   19400.0                        4
# 4                3936.0                   25400.0                        5
# 5                3936.0                   29600.0                        6
# 6                3936.0                   34300.0                        7
# 7                3936.0                   35400.0                        7
# 8                3936.0                   34500.0                        7
# 9                3936.0                   35600.0                        7
#
#          verif  seven_days_moving_average
# 0  4200.000000                4200.000000
# 1  4750.000000                4750.000000
# 2  4633.333333                4633.333333
# 3  4850.000000                4850.000000
# 4  5080.000000                5080.000000
# 5  4933.333333                4933.333333
# 6  4900.000000                4900.000000
# 7  5057.142857                5057.142857
# 8  4928.571429                4928.571429
# 9  5085.714286                5085.714286

# %% [markdown]
# Si on regarde les dernières lignes, on s'aperçoit qu'on a toujours notre problème

# %%
query = """
SELECT *,
AVG(visiteurs_count) OVER(
    ORDER BY DATE 
    ROWS BETWEEN 6 PRECEDING AND CURRENT ROW
    ) AS seven_daysmoving_average,
seven_daysmoving_average * 0.8 AS new_threshold
FROM capteurs
"""
duckdb.sql(query).df().tail(10)
# Out:
#           date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 20  2023-08-24    porte_a           4700.0        5           4920.0
# 21  2023-08-25    porte_a           5800.0        6           4920.0
# 22  2023-08-26    porte_a           6000.0        7           4920.0
# 23  2023-08-28    porte_a           4300.0        2           4920.0
# 24  2023-08-29    porte_a           4750.0        3           4920.0
# 25  2023-08-30    porte_a           5500.0        4           4920.0
# 26  2023-08-31    porte_a           4700.0        5           4920.0
# 27  2023-09-01    porte_a           5600.0        6           4700.0
# 28  2023-09-02    porte_a           4000.0        7           4700.0
# 29  2023-09-04    porte_a           4500.0        2           4700.0
#
#     threshold_twenty_pct  seven_daysmoving_average  new_threshold
# 20                3936.0               4785.714286    3828.571429
# 21                3936.0               5100.000000    4080.000000
# 22                3936.0               5242.857143    4194.285714
# 23                3936.0               5071.428571    4057.142857
# 24                3936.0               5135.714286    4108.571429
# 25                3936.0               5221.428571    4177.142857
# 26                3936.0               5107.142857    4085.714286
# 27                3760.0               5235.714286    4188.571429
# 28                3760.0               4978.571429    3982.857143
# 29                3760.0               4764.285714    3811.428571

# %% [markdown]
# Conclusion: ça permet de faire les 7 derniers jours, mais pas les 7 derniers Samedi !
