# %%
import pandas as pd
import duckdb
import random

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %% [markdown]
# ## La clause OVER

# %%
# Define the furniture data
furniture_data = [
    ("Chairs", "Chair 1", 5.2),
    ("Chairs", "Chair 2", 4.5),
    ("Chairs", "Chair 3", 6.8),
    ("Sofas", "Sofa 1", 25.5),
    ("Sofas", "Sofa 2", 20.3),
    ("Sofas", "Sofa 3", 30.0),
    ("Tables", "Table 1", 15.0),
    ("Tables", "Table 2", 12.5),
    ("Tables", "Table 3", 18.2),
]

# Create a pandas DataFrame from the predefined data
df = pd.DataFrame(furniture_data, columns=["category", "item", "weight"])

# Print the DataFrame
df
# Out:
#   category     item  weight
# 0   Chairs  Chair 1     5.2
# 1   Chairs  Chair 2     4.5
# 2   Chairs  Chair 3     6.8
# 3    Sofas   Sofa 1    25.5
# 4    Sofas   Sofa 2    20.3
# 5    Sofas   Sofa 3    30.0
# 6   Tables  Table 1    15.0
# 7   Tables  Table 2    12.5
# 8   Tables  Table 3    18.2

# %% [markdown]
# ### Over tout seul

# %% [markdown]
# On veut le poids total de tous les articles

# %%
query = """
SELECT  SUM(weight)  AS poids_total,
FROM df
"""
duckdb.sql(query).df()
# Out:
#    poids_total
# 0        138.0

# %% [markdown]
# On veut le poids total de tous les articles dans une colonne à part

# %%
query = """
SELECT *,
SUM(weight) OVER() AS poids_total,
FROM df
"""
duckdb.sql(query).df()
# Out:
#   category     item  weight  poids_total
# 0   Chairs  Chair 1     5.2        138.0
# 1   Chairs  Chair 2     4.5        138.0
# 2   Chairs  Chair 3     6.8        138.0
# 3    Sofas   Sofa 1    25.5        138.0
# 4    Sofas   Sofa 2    20.3        138.0
# 5    Sofas   Sofa 3    30.0        138.0
# 6   Tables  Table 1    15.0        138.0
# 7   Tables  Table 2    12.5        138.0
# 8   Tables  Table 3    18.2        138.0

# %% [markdown]
# <blockquote> Attends, tu nous as fait galérer à faire des GROUPING SETS + SELF JOIN pour avoir le total sur la droite de la table alors qu'on pouvait faire ça ?! </blockquote>
#
# C'était l'occasion de vous faire réviser le self join ;)
#
# Le Grouping Sets est surtout utile dans la situation où on veut la somme totale (sur l'ensemble) dans la même colonne que les sommes pour les sous-ensembles

# %% [markdown]
# Mais ce n'est pas tout ce qu'OVER peut faire:

# %% [markdown]
# ### Over(ORDER BY): running total

# %% [markdown]
# Il suffit ensuite de changer la fonction d'agrégation pour obtenir un running total:

# %%
query = """
SELECT *,
SUM(weight) OVER(ORDER BY item) AS poids_total,
FROM df
"""
duckdb.sql(query).df()
# Out:
#   category     item  weight  poids_total
# 0   Chairs  Chair 1     5.2          5.2
# 1   Chairs  Chair 2     4.5          9.7
# 2   Chairs  Chair 3     6.8         16.5
# 3    Sofas   Sofa 1    25.5         42.0
# 4    Sofas   Sofa 2    20.3         62.3
# 5    Sofas   Sofa 3    30.0         92.3
# 6   Tables  Table 1    15.0        107.3
# 7   Tables  Table 2    12.5        119.8
# 8   Tables  Table 3    18.2        138.0

# %% [markdown]
# Ou un moving average:

# %% [markdown]
# ### Over (ORDER BY): Moving average

# %%
query = """
SELECT *,
AVG(weight) OVER(ORDER BY item DESC) AS poids_total,
FROM df
"""
duckdb.sql(query).df()
# Out:
#   category     item  weight  poids_total
# 0   Tables  Table 3    18.2    18.200000
# 1   Tables  Table 2    12.5    15.350000
# 2   Tables  Table 1    15.0    15.233333
# 3    Sofas   Sofa 3    30.0    18.925000
# 4    Sofas   Sofa 2    20.3    19.200000
# 5    Sofas   Sofa 1    25.5    20.250000
# 6   Chairs  Chair 3     6.8    18.328571
# 7   Chairs  Chair 2     4.5    16.600000
# 8   Chairs  Chair 1     5.2    15.333333

# %% [markdown]
# ## Exercices

# %%
df = pd.read_csv("data/capteur_a_retrail.csv")
df
# Out:
#           date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0   2023-08-01    porte_a           4200.0        3           4920.0
# 1   2023-08-02    porte_a           5300.0        4           4920.0
# 2   2023-08-03    porte_a           4400.0        5           4920.0
# 3   2023-08-04    porte_a           5500.0        6           4920.0
# 4   2023-08-05    porte_a           6000.0        7           4920.0
# 5   2023-08-07    porte_a           4200.0        2           4920.0
# 6   2023-08-08    porte_a           4700.0        3           4920.0
# 7   2023-08-09    porte_a           5300.0        4           4920.0
# 8   2023-08-10    porte_a           4400.0        5           4920.0
# 9   2023-08-11    porte_a           5500.0        6           4920.0
# 10  2023-08-12    porte_a           6000.0        7           4920.0
# 11  2023-08-14    porte_a           3900.0        2           4920.0
# 12  2023-08-15    porte_a           4200.0        3           4920.0
# 13  2023-08-16    porte_a           4700.0        4           4920.0
# 14  2023-08-17    porte_a           3600.0        5           4920.0
# 15  2023-08-18    porte_a           5000.0        6           4920.0
# 16  2023-08-19    porte_a           5500.0        7           4920.0
# 17  2023-08-21    porte_a           4300.0        2           4920.0
# 18  2023-08-22    porte_a           4900.0        3           4920.0
# 19  2023-08-23    porte_a           5500.0        4           4920.0
# 20  2023-08-24    porte_a           4700.0        5           4920.0
# 21  2023-08-25    porte_a           5800.0        6           4920.0
# 22  2023-08-26    porte_a           6000.0        7           4920.0
# 23  2023-08-28    porte_a           4300.0        2           4920.0
# 24  2023-08-29    porte_a           4750.0        3           4920.0
# 25  2023-08-30    porte_a           5500.0        4           4920.0
# 26  2023-08-31    porte_a           4700.0        5           4920.0
# 27  2023-09-01    porte_a           5600.0        6           4700.0
# 28  2023-09-02    porte_a           4000.0        7           4700.0
# 29  2023-09-04    porte_a           4500.0        2           4700.0
#
#     threshold_twenty_pct
# 0                 3936.0
# 1                 3936.0
# 2                 3936.0
# 3                 3936.0
# 4                 3936.0
# 5                 3936.0
# 6                 3936.0
# 7                 3936.0
# 8                 3936.0
# 9                 3936.0
# 10                3936.0
# 11                3936.0
# 12                3936.0
# 13                3936.0
# 14                3936.0
# 15                3936.0
# 16                3936.0
# 17                3936.0
# 18                3936.0
# 19                3936.0
# 20                3936.0
# 21                3936.0
# 22                3936.0
# 23                3936.0
# 24                3936.0
# 25                3936.0
# 26                3936.0
# 27                3760.0
# 28                3760.0
# 29                3760.0

# %% [markdown]
# Récupérez la somme totale des visiteurs sur l'ensemble de la donnée :

# %%
query = """
SELECT 
    SUM(visiteurs_count) AS total_visiteur
FROM df
"""
duckdb.sql(query)
# Out:
# ┌────────────────┐
# │ total_visiteur │
# │     double     │
# ├────────────────┤
# │       146950.0 │
# └────────────────┘

# %%
# %load solutions/1sum_total.py
query = """
SELECT  SUM(visiteurs_count)  AS total_visiteurs,
FROM df
"""
duckdb.sql(query).df()
# Out:
#    total_visiteurs
# 0         146950.0

# %% [markdown]
# Utilisez OVER() pour avoir ce même total sur l'ensemble de la table, <br />
# Dans une nouvelle colonne "total_visiteurs"

# %%
query = """
SELECT 
    *,
    SUM(visiteurs_count) OVER() AS total_visiteur
FROM df
ORDER BY
    weekday
"""
duckdb.sql(query).df()
# Out:
#           date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0   2023-08-07    porte_a           4200.0        2           4920.0
# 1   2023-08-14    porte_a           3900.0        2           4920.0
# 2   2023-08-21    porte_a           4300.0        2           4920.0
# 3   2023-08-28    porte_a           4300.0        2           4920.0
# 4   2023-09-04    porte_a           4500.0        2           4700.0
# 5   2023-08-01    porte_a           4200.0        3           4920.0
# 6   2023-08-08    porte_a           4700.0        3           4920.0
# 7   2023-08-15    porte_a           4200.0        3           4920.0
# 8   2023-08-22    porte_a           4900.0        3           4920.0
# 9   2023-08-29    porte_a           4750.0        3           4920.0
# 10  2023-08-02    porte_a           5300.0        4           4920.0
# 11  2023-08-09    porte_a           5300.0        4           4920.0
# 12  2023-08-16    porte_a           4700.0        4           4920.0
# 13  2023-08-23    porte_a           5500.0        4           4920.0
# 14  2023-08-30    porte_a           5500.0        4           4920.0
# 15  2023-08-03    porte_a           4400.0        5           4920.0
# 16  2023-08-10    porte_a           4400.0        5           4920.0
# 17  2023-08-17    porte_a           3600.0        5           4920.0
# 18  2023-08-24    porte_a           4700.0        5           4920.0
# 19  2023-08-31    porte_a           4700.0        5           4920.0
# 20  2023-08-04    porte_a           5500.0        6           4920.0
# 21  2023-08-11    porte_a           5500.0        6           4920.0
# 22  2023-08-18    porte_a           5000.0        6           4920.0
# 23  2023-08-25    porte_a           5800.0        6           4920.0
# 24  2023-09-01    porte_a           5600.0        6           4700.0
# 25  2023-08-05    porte_a           6000.0        7           4920.0
# 26  2023-08-12    porte_a           6000.0        7           4920.0
# 27  2023-08-19    porte_a           5500.0        7           4920.0
# 28  2023-08-26    porte_a           6000.0        7           4920.0
# 29  2023-09-02    porte_a           4000.0        7           4700.0
#
#     threshold_twenty_pct  total_visiteur
# 0                 3936.0        146950.0
# 1                 3936.0        146950.0
# 2                 3936.0        146950.0
# 3                 3936.0        146950.0
# 4                 3760.0        146950.0
# 5                 3936.0        146950.0
# 6                 3936.0        146950.0
# 7                 3936.0        146950.0
# 8                 3936.0        146950.0
# 9                 3936.0        146950.0
# 10                3936.0        146950.0
# 11                3936.0        146950.0
# 12                3936.0        146950.0
# 13                3936.0        146950.0
# 14                3936.0        146950.0
# 15                3936.0        146950.0
# 16                3936.0        146950.0
# 17                3936.0        146950.0
# 18                3936.0        146950.0
# 19                3936.0        146950.0
# 20                3936.0        146950.0
# 21                3936.0        146950.0
# 22                3936.0        146950.0
# 23                3936.0        146950.0
# 24                3760.0        146950.0
# 25                3936.0        146950.0
# 26                3936.0        146950.0
# 27                3936.0        146950.0
# 28                3936.0        146950.0
# 29                3760.0        146950.0

# %%
# %load solutions/2sum_over.py
query = """
SELECT *, 
SUM(visiteurs_count) OVER() AS total_visiteurs,
FROM df
ORDER BY weekday
"""
duckdb.sql(query).df().head(10)
# Out:
#          date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0  2023-08-07    porte_a           4200.0        2           4920.0
# 1  2023-08-14    porte_a           3900.0        2           4920.0
# 2  2023-08-21    porte_a           4300.0        2           4920.0
# 3  2023-08-28    porte_a           4300.0        2           4920.0
# 4  2023-09-04    porte_a           4500.0        2           4700.0
# 5  2023-08-01    porte_a           4200.0        3           4920.0
# 6  2023-08-08    porte_a           4700.0        3           4920.0
# 7  2023-08-15    porte_a           4200.0        3           4920.0
# 8  2023-08-22    porte_a           4900.0        3           4920.0
# 9  2023-08-29    porte_a           4750.0        3           4920.0
#
#    threshold_twenty_pct  total_visiteurs
# 0                3936.0         146950.0
# 1                3936.0         146950.0
# 2                3936.0         146950.0
# 3                3936.0         146950.0
# 4                3760.0         146950.0
# 5                3936.0         146950.0
# 6                3936.0         146950.0
# 7                3936.0         146950.0
# 8                3936.0         146950.0
# 9                3936.0         146950.0

# %% [markdown]
# Votre manager veut que la colonne total contienne le total progressif <br />
# des visiteurs sur le mois.

# %%
query = """
SELECT 
    *,
    SUM(visiteurs_count) OVER(ORDER BY date) AS running_total_visiteurs
FROM df

"""
duckdb.sql(query).df()
# Out:
#           date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0   2023-08-01    porte_a           4200.0        3           4920.0
# 1   2023-08-02    porte_a           5300.0        4           4920.0
# 2   2023-08-03    porte_a           4400.0        5           4920.0
# 3   2023-08-04    porte_a           5500.0        6           4920.0
# 4   2023-08-05    porte_a           6000.0        7           4920.0
# 5   2023-08-07    porte_a           4200.0        2           4920.0
# 6   2023-08-08    porte_a           4700.0        3           4920.0
# 7   2023-08-09    porte_a           5300.0        4           4920.0
# 8   2023-08-10    porte_a           4400.0        5           4920.0
# 9   2023-08-11    porte_a           5500.0        6           4920.0
# 10  2023-08-12    porte_a           6000.0        7           4920.0
# 11  2023-08-14    porte_a           3900.0        2           4920.0
# 12  2023-08-15    porte_a           4200.0        3           4920.0
# 13  2023-08-16    porte_a           4700.0        4           4920.0
# 14  2023-08-17    porte_a           3600.0        5           4920.0
# 15  2023-08-18    porte_a           5000.0        6           4920.0
# 16  2023-08-19    porte_a           5500.0        7           4920.0
# 17  2023-08-21    porte_a           4300.0        2           4920.0
# 18  2023-08-22    porte_a           4900.0        3           4920.0
# 19  2023-08-23    porte_a           5500.0        4           4920.0
# 20  2023-08-24    porte_a           4700.0        5           4920.0
# 21  2023-08-25    porte_a           5800.0        6           4920.0
# 22  2023-08-26    porte_a           6000.0        7           4920.0
# 23  2023-08-28    porte_a           4300.0        2           4920.0
# 24  2023-08-29    porte_a           4750.0        3           4920.0
# 25  2023-08-30    porte_a           5500.0        4           4920.0
# 26  2023-08-31    porte_a           4700.0        5           4920.0
# 27  2023-09-01    porte_a           5600.0        6           4700.0
# 28  2023-09-02    porte_a           4000.0        7           4700.0
# 29  2023-09-04    porte_a           4500.0        2           4700.0
#
#     threshold_twenty_pct  running_total_visiteurs
# 0                 3936.0                   4200.0
# 1                 3936.0                   9500.0
# 2                 3936.0                  13900.0
# 3                 3936.0                  19400.0
# 4                 3936.0                  25400.0
# 5                 3936.0                  29600.0
# 6                 3936.0                  34300.0
# 7                 3936.0                  39600.0
# 8                 3936.0                  44000.0
# 9                 3936.0                  49500.0
# 10                3936.0                  55500.0
# 11                3936.0                  59400.0
# 12                3936.0                  63600.0
# 13                3936.0                  68300.0
# 14                3936.0                  71900.0
# 15                3936.0                  76900.0
# 16                3936.0                  82400.0
# 17                3936.0                  86700.0
# 18                3936.0                  91600.0
# 19                3936.0                  97100.0
# 20                3936.0                 101800.0
# 21                3936.0                 107600.0
# 22                3936.0                 113600.0
# 23                3936.0                 117900.0
# 24                3936.0                 122650.0
# 25                3936.0                 128150.0
# 26                3936.0                 132850.0
# 27                3760.0                 138450.0
# 28                3760.0                 142450.0
# 29                3760.0                 146950.0

# %%
# %load solutions/3progressive_total.py
query = """
SELECT *, 
SUM(visiteurs_count) OVER(ORDER BY date) AS total_visiteurs,
FROM df
ORDER BY date
"""
duckdb.sql(query).df().head()
# Out:
#          date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0  2023-08-01    porte_a           4200.0        3           4920.0
# 1  2023-08-02    porte_a           5300.0        4           4920.0
# 2  2023-08-03    porte_a           4400.0        5           4920.0
# 3  2023-08-04    porte_a           5500.0        6           4920.0
# 4  2023-08-05    porte_a           6000.0        7           4920.0
#
#    threshold_twenty_pct  total_visiteurs
# 0                3936.0           4200.0
# 1                3936.0           9500.0
# 2                3936.0          13900.0
# 3                3936.0          19400.0
# 4                3936.0          25400.0

# %% [markdown]
# Il veut maintenant avoir une moyenne de visiteurs sur le mois <br />
# qui se met à jour progressivement en fonction des résultats de la journée

# %%
query = """
SELECT 
    *,
    AVG(visiteurs_count) OVER(ORDER BY date) AS running_AVG_visiteurs
FROM df

"""
duckdb.sql(query).df()
# Out:
#           date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0   2023-08-01    porte_a           4200.0        3           4920.0
# 1   2023-08-02    porte_a           5300.0        4           4920.0
# 2   2023-08-03    porte_a           4400.0        5           4920.0
# 3   2023-08-04    porte_a           5500.0        6           4920.0
# 4   2023-08-05    porte_a           6000.0        7           4920.0
# 5   2023-08-07    porte_a           4200.0        2           4920.0
# 6   2023-08-08    porte_a           4700.0        3           4920.0
# 7   2023-08-09    porte_a           5300.0        4           4920.0
# 8   2023-08-10    porte_a           4400.0        5           4920.0
# 9   2023-08-11    porte_a           5500.0        6           4920.0
# 10  2023-08-12    porte_a           6000.0        7           4920.0
# 11  2023-08-14    porte_a           3900.0        2           4920.0
# 12  2023-08-15    porte_a           4200.0        3           4920.0
# 13  2023-08-16    porte_a           4700.0        4           4920.0
# 14  2023-08-17    porte_a           3600.0        5           4920.0
# 15  2023-08-18    porte_a           5000.0        6           4920.0
# 16  2023-08-19    porte_a           5500.0        7           4920.0
# 17  2023-08-21    porte_a           4300.0        2           4920.0
# 18  2023-08-22    porte_a           4900.0        3           4920.0
# 19  2023-08-23    porte_a           5500.0        4           4920.0
# 20  2023-08-24    porte_a           4700.0        5           4920.0
# 21  2023-08-25    porte_a           5800.0        6           4920.0
# 22  2023-08-26    porte_a           6000.0        7           4920.0
# 23  2023-08-28    porte_a           4300.0        2           4920.0
# 24  2023-08-29    porte_a           4750.0        3           4920.0
# 25  2023-08-30    porte_a           5500.0        4           4920.0
# 26  2023-08-31    porte_a           4700.0        5           4920.0
# 27  2023-09-01    porte_a           5600.0        6           4700.0
# 28  2023-09-02    porte_a           4000.0        7           4700.0
# 29  2023-09-04    porte_a           4500.0        2           4700.0
#
#     threshold_twenty_pct  running_AVG_visiteurs
# 0                 3936.0            4200.000000
# 1                 3936.0            4750.000000
# 2                 3936.0            4633.333333
# 3                 3936.0            4850.000000
# 4                 3936.0            5080.000000
# 5                 3936.0            4933.333333
# 6                 3936.0            4900.000000
# 7                 3936.0            4950.000000
# 8                 3936.0            4888.888889
# 9                 3936.0            4950.000000
# 10                3936.0            5045.454545
# 11                3936.0            4950.000000
# 12                3936.0            4892.307692
# 13                3936.0            4878.571429
# 14                3936.0            4793.333333
# 15                3936.0            4806.250000
# 16                3936.0            4847.058824
# 17                3936.0            4816.666667
# 18                3936.0            4821.052632
# 19                3936.0            4855.000000
# 20                3936.0            4847.619048
# 21                3936.0            4890.909091
# 22                3936.0            4939.130435
# 23                3936.0            4912.500000
# 24                3936.0            4906.000000
# 25                3936.0            4928.846154
# 26                3936.0            4920.370370
# 27                3760.0            4944.642857
# 28                3760.0            4912.068966
# 29                3760.0            4898.333333

# %%
# %load solutions/4progressive_avg.py
query = """
SELECT *, 
AVG(visiteurs_count) OVER(ORDER BY date) AS total_visiteurs,
FROM df
ORDER BY date
"""
duckdb.sql(query).df()
# Out:
#           date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0   2023-08-01    porte_a           4200.0        3           4920.0
# 1   2023-08-02    porte_a           5300.0        4           4920.0
# 2   2023-08-03    porte_a           4400.0        5           4920.0
# 3   2023-08-04    porte_a           5500.0        6           4920.0
# 4   2023-08-05    porte_a           6000.0        7           4920.0
# 5   2023-08-07    porte_a           4200.0        2           4920.0
# 6   2023-08-08    porte_a           4700.0        3           4920.0
# 7   2023-08-09    porte_a           5300.0        4           4920.0
# 8   2023-08-10    porte_a           4400.0        5           4920.0
# 9   2023-08-11    porte_a           5500.0        6           4920.0
# 10  2023-08-12    porte_a           6000.0        7           4920.0
# 11  2023-08-14    porte_a           3900.0        2           4920.0
# 12  2023-08-15    porte_a           4200.0        3           4920.0
# 13  2023-08-16    porte_a           4700.0        4           4920.0
# 14  2023-08-17    porte_a           3600.0        5           4920.0
# 15  2023-08-18    porte_a           5000.0        6           4920.0
# 16  2023-08-19    porte_a           5500.0        7           4920.0
# 17  2023-08-21    porte_a           4300.0        2           4920.0
# 18  2023-08-22    porte_a           4900.0        3           4920.0
# 19  2023-08-23    porte_a           5500.0        4           4920.0
# 20  2023-08-24    porte_a           4700.0        5           4920.0
# 21  2023-08-25    porte_a           5800.0        6           4920.0
# 22  2023-08-26    porte_a           6000.0        7           4920.0
# 23  2023-08-28    porte_a           4300.0        2           4920.0
# 24  2023-08-29    porte_a           4750.0        3           4920.0
# 25  2023-08-30    porte_a           5500.0        4           4920.0
# 26  2023-08-31    porte_a           4700.0        5           4920.0
# 27  2023-09-01    porte_a           5600.0        6           4700.0
# 28  2023-09-02    porte_a           4000.0        7           4700.0
# 29  2023-09-04    porte_a           4500.0        2           4700.0
#
#     threshold_twenty_pct  total_visiteurs
# 0                 3936.0      4200.000000
# 1                 3936.0      4750.000000
# 2                 3936.0      4633.333333
# 3                 3936.0      4850.000000
# 4                 3936.0      5080.000000
# 5                 3936.0      4933.333333
# 6                 3936.0      4900.000000
# 7                 3936.0      4950.000000
# 8                 3936.0      4888.888889
# 9                 3936.0      4950.000000
# 10                3936.0      5045.454545
# 11                3936.0      4950.000000
# 12                3936.0      4892.307692
# 13                3936.0      4878.571429
# 14                3936.0      4793.333333
# 15                3936.0      4806.250000
# 16                3936.0      4847.058824
# 17                3936.0      4816.666667
# 18                3936.0      4821.052632
# 19                3936.0      4855.000000
# 20                3936.0      4847.619048
# 21                3936.0      4890.909091
# 22                3936.0      4939.130435
# 23                3936.0      4912.500000
# 24                3936.0      4906.000000
# 25                3936.0      4928.846154
# 26                3936.0      4920.370370
# 27                3760.0      4944.642857
# 28                3760.0      4912.068966
# 29                3760.0      4898.333333

# %% [markdown]
# C'est bien, mais le P.O. estime qu'il n'est pas nécessaire <br />
# de garder les anciennes valeurs au delà d'une semaine.
#
# Il veut un "moving average" uniquement sur les 7 derniers jours.
