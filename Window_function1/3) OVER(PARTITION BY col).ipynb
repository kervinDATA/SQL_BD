# %% [markdown]
# Conclusion: ça permet de faire les 7 derniers jours, mais on aimerait que ça reprenne à 0 pour le mois de Septembre !

# %%
import pandas as pd
import duckdb

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
data = {
    'name': ['Toufik', 'Jean-Nicolas', 'Daniel', 'Kaouter', 'Sylvie',
             'Sebastien', 'Diane', 'Romain', 'François', 'Anna',
             'Zeinaba', 'Gregory', 'Karima', 'Arthur', 'Benjamin'],
    'wage': [60000, 75000, 55000, 80000, 70000,
             90000, 65000, 72000, 68000, 85000,
             100000, 120000, 95000, 83000, 110000],
    'department': ['IT', 'HR', 'SALES', 'IT', 'IT',
                   'HR', 'SALES', 'IT', 'HR', 'SALES',
                   'IT', 'IT', 'HR', 'SALES', 'CEO']
}
wages = pd.DataFrame(data)
wages.assign(
    max_per_dpt = lambda df_: df_[["department", "wage"]].groupby("department").transform("max")
).sort_values("department")
# Out:
#             name    wage department  max_per_dpt
# 14      Benjamin  110000        CEO       110000
# 1   Jean-Nicolas   75000         HR        95000
# 5      Sebastien   90000         HR        95000
# 8       François   68000         HR        95000
# 12        Karima   95000         HR        95000
# 0         Toufik   60000         IT       120000
# 3        Kaouter   80000         IT       120000
# 4         Sylvie   70000         IT       120000
# 7         Romain   72000         IT       120000
# 10       Zeinaba  100000         IT       120000
# 11       Gregory  120000         IT       120000
# 2         Daniel   55000      SALES        85000
# 6          Diane   65000      SALES        85000
# 9           Anna   85000      SALES        85000
# 13        Arthur   83000      SALES        85000

# %% [markdown]
# On aimerait savoir quel est le plus gros salaire par département ?

# %%
query = """
SELECT department,
MAX(wage)
FROM wages
GROUP BY department
"""
duckdb.sql(query).df()
# Out:
#   department  max(wage)
# 0         HR      95000
# 1        CEO     110000
# 2      SALES      85000
# 3         IT     120000

# %% [markdown]
# Maintenant, on aimerait l'avoir en face de chaque salaire pour calculer <br />
# les écarts de salaires entre les employés d'un même département

# %% [markdown]
# ## La syntaxe "PARTITION BY"

# %% [markdown]
# Il faut imaginer que vous faites une "sous-table" pour chaque département, <br />
# et un MAX(wage) OVER() pour chacune de ces sous-tables

# %%
for department in wages["department"].unique().tolist():
    subset = wages[ wages["department"] == department ]
    query = """
    SELECT *,
    MAX(wage) OVER() AS max_dpt_wage
    FROM subset
    ORDER BY department
    """
    display(duckdb.sql(query).df())
# Out:
#       name    wage department  max_dpt_wage
# 0   Toufik   60000         IT        120000
# 1  Kaouter   80000         IT        120000
# 2   Sylvie   70000         IT        120000
# 3   Romain   72000         IT        120000
# 4  Zeinaba  100000         IT        120000
# 5  Gregory  120000         IT        120000
#            name   wage department  max_dpt_wage
# 0  Jean-Nicolas  75000         HR         95000
# 1     Sebastien  90000         HR         95000
# 2      François  68000         HR         95000
# 3        Karima  95000         HR         95000
#      name   wage department  max_dpt_wage
# 0  Daniel  55000      SALES         85000
# 1   Diane  65000      SALES         85000
# 2    Anna  85000      SALES         85000
# 3  Arthur  83000      SALES         85000
#        name    wage department  max_dpt_wage
# 0  Benjamin  110000        CEO        110000

# %% [markdown]
# Pour faire ça efficacement, on peut utiliser la clause OVER(PARTITION BY ...)

# %%
query = """
SELECT *,
MAX(wage) OVER(PARTITION BY department) AS max_dpt_wage
FROM wages
ORDER BY department
"""
duckdb.sql(query).df()
# Out:
#             name    wage department  max_dpt_wage
# 0       Benjamin  110000        CEO        110000
# 1   Jean-Nicolas   75000         HR         95000
# 2      Sebastien   90000         HR         95000
# 3       François   68000         HR         95000
# 4         Karima   95000         HR         95000
# 5         Toufik   60000         IT        120000
# 6        Kaouter   80000         IT        120000
# 7         Sylvie   70000         IT        120000
# 8         Romain   72000         IT        120000
# 9        Zeinaba  100000         IT        120000
# 10       Gregory  120000         IT        120000
# 11        Daniel   55000      SALES         85000
# 12         Diane   65000      SALES         85000
# 13          Anna   85000      SALES         85000
# 14        Arthur   83000      SALES         85000

# %%
wages.assign(
    max_wage= lambda df_: 
                df_.groupby(["department"])
                .transform("max")["wage"]
).sort_values("department")
# Out:
#             name    wage department  max_wage
# 14      Benjamin  110000        CEO    110000
# 1   Jean-Nicolas   75000         HR     95000
# 5      Sebastien   90000         HR     95000
# 8       François   68000         HR     95000
# 12        Karima   95000         HR     95000
# 0         Toufik   60000         IT    120000
# 3        Kaouter   80000         IT    120000
# 4         Sylvie   70000         IT    120000
# 7         Romain   72000         IT    120000
# 10       Zeinaba  100000         IT    120000
# 11       Gregory  120000         IT    120000
# 2         Daniel   55000      SALES     85000
# 6          Diane   65000      SALES     85000
# 9           Anna   85000      SALES     85000
# 13        Arthur   83000      SALES     85000

# %%
wages.groupby(["department"]).transform("max")
# Out:
#          name    wage
# 0     Zeinaba  120000
# 1   Sebastien   95000
# 2       Diane   85000
# 3     Zeinaba  120000
# 4     Zeinaba  120000
# 5   Sebastien   95000
# 6       Diane   85000
# 7     Zeinaba  120000
# 8   Sebastien   95000
# 9       Diane   85000
# 10    Zeinaba  120000
# 11    Zeinaba  120000
# 12  Sebastien   95000
# 13      Diane   85000
# 14   Benjamin  110000

# %% [markdown]
# ## Exercice:
# Calculez le salaire moyen par department

# %%
query = """
SELECT
    *,
    AVG(wage) OVER(PARTITION BY department) AS mean_dpt_wage
FROM wages
ORDER BY mean_dpt_wage DESC

"""
duckdb.sql(query).df()
# Out:
#             name    wage department  mean_dpt_wage
# 0       Benjamin  110000        CEO  110000.000000
# 1         Toufik   60000         IT   83666.666667
# 2        Kaouter   80000         IT   83666.666667
# 3         Sylvie   70000         IT   83666.666667
# 4         Romain   72000         IT   83666.666667
# 5        Zeinaba  100000         IT   83666.666667
# 6        Gregory  120000         IT   83666.666667
# 7   Jean-Nicolas   75000         HR   82000.000000
# 8      Sebastien   90000         HR   82000.000000
# 9       François   68000         HR   82000.000000
# 10        Karima   95000         HR   82000.000000
# 11        Daniel   55000      SALES   72000.000000
# 12         Diane   65000      SALES   72000.000000
# 13          Anna   85000      SALES   72000.000000
# 14        Arthur   83000      SALES   72000.000000

# %%
# %load solutions/8partition_by_simple.py
query = """
SELECT *,
AVG(wage) OVER(PARTITION BY department) AS mean_dpt_wage
FROM wages
ORDER BY department
"""
duckdb.sql(query).df()

# %% [markdown]
# Créez une nouvelle colonne qui indique si un salarié est au max de son département

# %%
query = """
SELECT *,
MAX(wage) OVER(PARTITION BY department) AS max_dpt_wage,
wage >= max_dpt_wage AS is_max
FROM wages
ORDER BY department
"""
duckdb.sql(query).df()
# Out:
#             name    wage department  max_dpt_wage  is_max
# 0       Benjamin  110000        CEO        110000    True
# 1   Jean-Nicolas   75000         HR         95000   False
# 2      Sebastien   90000         HR         95000   False
# 3       François   68000         HR         95000   False
# 4         Karima   95000         HR         95000    True
# 5         Toufik   60000         IT        120000   False
# 6        Kaouter   80000         IT        120000   False
# 7         Sylvie   70000         IT        120000   False
# 8         Romain   72000         IT        120000   False
# 9        Zeinaba  100000         IT        120000   False
# 10       Gregory  120000         IT        120000    True
# 11        Daniel   55000      SALES         85000   False
# 12         Diane   65000      SALES         85000   False
# 13          Anna   85000      SALES         85000    True
# 14        Arthur   83000      SALES         85000   False

# %%
# %load solutions/9max_per_dpt.py
query = """
SELECT *,
MAX(wage) OVER(PARTITION BY department) AS max_dpt_wage,
wage >= max_dpt_wage AS is_max
FROM wages
ORDER BY department
"""
duckdb.sql(query).df()
# Out:
#             name    wage department  max_dpt_wage  is_max
# 0       Benjamin  110000        CEO        110000    True
# 1   Jean-Nicolas   75000         HR         95000   False
# 2      Sebastien   90000         HR         95000   False
# 3       François   68000         HR         95000   False
# 4         Karima   95000         HR         95000    True
# 5         Toufik   60000         IT        120000   False
# 6        Kaouter   80000         IT        120000   False
# 7         Sylvie   70000         IT        120000   False
# 8         Romain   72000         IT        120000   False
# 9        Zeinaba  100000         IT        120000   False
# 10       Gregory  120000         IT        120000    True
# 11        Daniel   55000      SALES         85000   False
# 12         Diane   65000      SALES         85000   False
# 13          Anna   85000      SALES         85000    True
# 14        Arthur   83000      SALES         85000   False

# %% [markdown]
# Servez-vous de ça pour calculer le 2e MAX.
#
# Indice: utilisez une CTE pour stocker le 1er salaire maximum par département, <br />
# puis filtrer cette CTE pour exclure le MAX et refaites la même procédure <br />
# pour trouver le nouveau MAX sur les records restants

# %%
query = """
WITH max_salaries_per_dpt AS(
SELECT
    *,
    MAX(wage) OVER(PARTITION BY department) AS max_dpt_wage,
    wage >= max_dpt_wage AS max_salary
FROM wages
ORDER BY department
-- on va garder que les max_salary = False
)

SELECT
    *,
    MAX(wage) OVER(PARTITION BY department) AS max_dpt_wage
FROM max_salaries_per_dpt
WHERE max_salary = False

"""
duckdb.sql(query).df()
# Out:
#             name    wage department  max_dpt_wage  max_salary  max_dpt_wage_1
# 0   Jean-Nicolas   75000         HR         95000       False           90000
# 1      Sebastien   90000         HR         95000       False           90000
# 2       François   68000         HR         95000       False           90000
# 3         Arthur   83000      SALES         85000       False           83000
# 4         Daniel   55000      SALES         85000       False           83000
# 5          Diane   65000      SALES         85000       False           83000
# 6         Sylvie   70000         IT        120000       False          100000
# 7         Romain   72000         IT        120000       False          100000
# 8        Zeinaba  100000         IT        120000       False          100000
# 9         Toufik   60000         IT        120000       False          100000
# 10       Kaouter   80000         IT        120000       False          100000

# %%
# %load solutions/10second_max_per_dpt.py
query = """
WITH max_salaries_per_dpt AS (
    SELECT *,
    MAX(wage) OVER(PARTITION BY department) AS max_dpt_wage,
    wage >= max_dpt_wage AS max_salary,
    FROM wages
    -- QUALIFY max_salary = False
    ORDER BY department
)


SELECT *,
MAX(wage) OVER(PARTITION BY department) AS max_dpt_wage
FROM max_salaries_per_dpt
WHERE max_salary = False
"""
duckdb.sql(query).df()
# Out:
#             name    wage department  max_dpt_wage  max_salary  max_dpt_wage_1
# 0   Jean-Nicolas   75000         HR         95000       False           90000
# 1      Sebastien   90000         HR         95000       False           90000
# 2       François   68000         HR         95000       False           90000
# 3         Toufik   60000         IT        120000       False          100000
# 4        Kaouter   80000         IT        120000       False          100000
# 5         Sylvie   70000         IT        120000       False          100000
# 6         Romain   72000         IT        120000       False          100000
# 7        Zeinaba  100000         IT        120000       False          100000
# 8         Daniel   55000      SALES         85000       False           83000
# 9          Diane   65000      SALES         85000       False           83000
# 10        Arthur   83000      SALES         85000       False           83000

# %% [markdown]
# ## Résolution du problème initial

# %%
capteurs = pd.read_csv("data/capteur_a_retrail.csv")
capteurs.head(6)
# Out:
#          date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0  2023-08-01    porte_a           4200.0        3           4920.0
# 1  2023-08-02    porte_a           5300.0        4           4920.0
# 2  2023-08-03    porte_a           4400.0        5           4920.0
# 3  2023-08-04    porte_a           5500.0        6           4920.0
# 4  2023-08-05    porte_a           6000.0        7           4920.0
# 5  2023-08-07    porte_a           4200.0        2           4920.0
#
#    threshold_twenty_pct
# 0                3936.0
# 1                3936.0
# 2                3936.0
# 3                3936.0
# 4                3936.0
# 5                3936.0

# %% [markdown]
# Mettez en face de chaque visiteurs_count la moyenne sur les 7 derniers jours, <br />
# en partitionnant la table en fonction du jour de la semaine, <br />
# puis multipliez cette colonne par 0.8 pour créer votre nouveau seuil

# %%
query = """
SELECT
    *,
    AVG(visiteurs_count) OVER(PARTITION BY weekday ROWS BETWEEN 6 PRECEDING and CURRENT ROW) AS avg_last_seven_same_days,
    avg_last_seven_same_days * 0.8 AS threshold
FROM capteurs

"""
duckdb.sql(query).df()
# Out:
#           date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0   2023-08-05    porte_a           6000.0        7           4920.0
# 1   2023-08-12    porte_a           6000.0        7           4920.0
# 2   2023-08-19    porte_a           5500.0        7           4920.0
# 3   2023-08-26    porte_a           6000.0        7           4920.0
# 4   2023-09-02    porte_a           4000.0        7           4700.0
# 5   2023-08-07    porte_a           4200.0        2           4920.0
# 6   2023-08-14    porte_a           3900.0        2           4920.0
# 7   2023-08-21    porte_a           4300.0        2           4920.0
# 8   2023-08-28    porte_a           4300.0        2           4920.0
# 9   2023-09-04    porte_a           4500.0        2           4700.0
# 10  2023-08-03    porte_a           4400.0        5           4920.0
# 11  2023-08-10    porte_a           4400.0        5           4920.0
# 12  2023-08-17    porte_a           3600.0        5           4920.0
# 13  2023-08-24    porte_a           4700.0        5           4920.0
# 14  2023-08-31    porte_a           4700.0        5           4920.0
# 15  2023-08-01    porte_a           4200.0        3           4920.0
# 16  2023-08-08    porte_a           4700.0        3           4920.0
# 17  2023-08-15    porte_a           4200.0        3           4920.0
# 18  2023-08-22    porte_a           4900.0        3           4920.0
# 19  2023-08-29    porte_a           4750.0        3           4920.0
# 20  2023-08-04    porte_a           5500.0        6           4920.0
# 21  2023-08-11    porte_a           5500.0        6           4920.0
# 22  2023-08-18    porte_a           5000.0        6           4920.0
# 23  2023-08-25    porte_a           5800.0        6           4920.0
# 24  2023-09-01    porte_a           5600.0        6           4700.0
# 25  2023-08-02    porte_a           5300.0        4           4920.0
# 26  2023-08-09    porte_a           5300.0        4           4920.0
# 27  2023-08-16    porte_a           4700.0        4           4920.0
# 28  2023-08-23    porte_a           5500.0        4           4920.0
# 29  2023-08-30    porte_a           5500.0        4           4920.0
#
#     threshold_twenty_pct  avg_last_seven_same_days    threshold
# 0                 3936.0               6000.000000  4800.000000
# 1                 3936.0               6000.000000  4800.000000
# 2                 3936.0               5833.333333  4666.666667
# 3                 3936.0               5875.000000  4700.000000
# 4                 3760.0               5500.000000  4400.000000
# 5                 3936.0               4200.000000  3360.000000
# 6                 3936.0               4050.000000  3240.000000
# 7                 3936.0               4133.333333  3306.666667
# 8                 3936.0               4175.000000  3340.000000
# 9                 3760.0               4240.000000  3392.000000
# 10                3936.0               4400.000000  3520.000000
# 11                3936.0               4400.000000  3520.000000
# 12                3936.0               4133.333333  3306.666667
# 13                3936.0               4275.000000  3420.000000
# 14                3936.0               4360.000000  3488.000000
# 15                3936.0               4200.000000  3360.000000
# 16                3936.0               4450.000000  3560.000000
# 17                3936.0               4366.666667  3493.333333
# 18                3936.0               4500.000000  3600.000000
# 19                3936.0               4550.000000  3640.000000
# 20                3936.0               5500.000000  4400.000000
# 21                3936.0               5500.000000  4400.000000
# 22                3936.0               5333.333333  4266.666667
# 23                3936.0               5450.000000  4360.000000
# 24                3760.0               5480.000000  4384.000000
# 25                3936.0               5300.000000  4240.000000
# 26                3936.0               5300.000000  4240.000000
# 27                3936.0               5100.000000  4080.000000
# 28                3936.0               5200.000000  4160.000000
# 29                3936.0               5260.000000  4208.000000

# %%
# %load solutions/11partition_by_weekday.py
query = """
SELECT *,
AVG(visiteurs_count) OVER(
    PARTITION BY weekday 
    ROWS BETWEEN 6 PRECEDING 
    AND CURRENT ROW
    ) AS avg_last_seven_same_days,
avg_last_seven_same_days * 0.8 as threshold
FROM capteurs
"""
df = duckdb.sql(query).df()
df
# Out:
#           date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0   2023-08-03    porte_a           4400.0        5           4920.0
# 1   2023-08-10    porte_a           4400.0        5           4920.0
# 2   2023-08-17    porte_a           3600.0        5           4920.0
# 3   2023-08-24    porte_a           4700.0        5           4920.0
# 4   2023-08-31    porte_a           4700.0        5           4920.0
# 5   2023-08-01    porte_a           4200.0        3           4920.0
# 6   2023-08-08    porte_a           4700.0        3           4920.0
# 7   2023-08-15    porte_a           4200.0        3           4920.0
# 8   2023-08-22    porte_a           4900.0        3           4920.0
# 9   2023-08-29    porte_a           4750.0        3           4920.0
# 10  2023-08-04    porte_a           5500.0        6           4920.0
# 11  2023-08-11    porte_a           5500.0        6           4920.0
# 12  2023-08-18    porte_a           5000.0        6           4920.0
# 13  2023-08-25    porte_a           5800.0        6           4920.0
# 14  2023-09-01    porte_a           5600.0        6           4700.0
# 15  2023-08-07    porte_a           4200.0        2           4920.0
# 16  2023-08-14    porte_a           3900.0        2           4920.0
# 17  2023-08-21    porte_a           4300.0        2           4920.0
# 18  2023-08-28    porte_a           4300.0        2           4920.0
# 19  2023-09-04    porte_a           4500.0        2           4700.0
# 20  2023-08-05    porte_a           6000.0        7           4920.0
# 21  2023-08-12    porte_a           6000.0        7           4920.0
# 22  2023-08-19    porte_a           5500.0        7           4920.0
# 23  2023-08-26    porte_a           6000.0        7           4920.0
# 24  2023-09-02    porte_a           4000.0        7           4700.0
# 25  2023-08-02    porte_a           5300.0        4           4920.0
# 26  2023-08-09    porte_a           5300.0        4           4920.0
# 27  2023-08-16    porte_a           4700.0        4           4920.0
# 28  2023-08-23    porte_a           5500.0        4           4920.0
# 29  2023-08-30    porte_a           5500.0        4           4920.0
#
#     threshold_twenty_pct  avg_last_seven_same_days    threshold
# 0                 3936.0               4400.000000  3520.000000
# 1                 3936.0               4400.000000  3520.000000
# 2                 3936.0               4133.333333  3306.666667
# 3                 3936.0               4275.000000  3420.000000
# 4                 3936.0               4360.000000  3488.000000
# 5                 3936.0               4200.000000  3360.000000
# 6                 3936.0               4450.000000  3560.000000
# 7                 3936.0               4366.666667  3493.333333
# 8                 3936.0               4500.000000  3600.000000
# 9                 3936.0               4550.000000  3640.000000
# 10                3936.0               5500.000000  4400.000000
# 11                3936.0               5500.000000  4400.000000
# 12                3936.0               5333.333333  4266.666667
# 13                3936.0               5450.000000  4360.000000
# 14                3760.0               5480.000000  4384.000000
# 15                3936.0               4200.000000  3360.000000
# 16                3936.0               4050.000000  3240.000000
# 17                3936.0               4133.333333  3306.666667
# 18                3936.0               4175.000000  3340.000000
# 19                3760.0               4240.000000  3392.000000
# 20                3936.0               6000.000000  4800.000000
# 21                3936.0               6000.000000  4800.000000
# 22                3936.0               5833.333333  4666.666667
# 23                3936.0               5875.000000  4700.000000
# 24                3760.0               5500.000000  4400.000000
# 25                3936.0               5300.000000  4240.000000
# 26                3936.0               5300.000000  4240.000000
# 27                3936.0               5100.000000  4080.000000
# 28                3936.0               5200.000000  4160.000000
# 29                3936.0               5260.000000  4208.000000

# %% [markdown]
# Vérification: le premier Samedi de Septembre devrait déclencher une alerte:

# %%
colors = {
    1:'background-color: red',
}


def highlight_day(s):
    return [colors.get(s.loc['visiteurs_count'] < s.loc['threshold']) for v in s.index]


df.style.apply(highlight_day, axis=1)
# Out:
# <style type="text/css">
# #T_ec80a_row24_col0, #T_ec80a_row24_col1, #T_ec80a_row24_col2, #T_ec80a_row24_col3, #T_ec80a_row24_col4, #T_ec80a_row24_col5, #T_ec80a_row24_col6, #T_ec80a_row24_col7 {
#   background-color: red;
# }
# </style>
# <table id="T_ec80a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec80a_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_ec80a_level0_col1" class="col_heading level0 col1" >capteur_id</th>
#       <th id="T_ec80a_level0_col2" class="col_heading level0 col2" >visiteurs_count</th>
#       <th id="T_ec80a_level0_col3" class="col_heading level0 col3" >weekday</th>
#       <th id="T_ec80a_level0_col4" class="col_heading level0 col4" >moyenne_du_mois</th>
#       <th id="T_ec80a_level0_col5" class="col_heading level0 col5" >threshold_twenty_pct</th>
#       <th id="T_ec80a_level0_col6" class="col_heading level0 col6" >avg_last_seven_same_days</th>
#       <th id="T_ec80a_level0_col7" class="col_heading level0 col7" >threshold</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec80a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ec80a_row0_col0" class="data row0 col0" >2023-08-03</td>
#       <td id="T_ec80a_row0_col1" class="data row0 col1" >porte_a</td>
#       <td id="T_ec80a_row0_col2" class="data row0 col2" >4400.000000</td>
#       <td id="T_ec80a_row0_col3" class="data row0 col3" >5</td>
#       <td id="T_ec80a_row0_col4" class="data row0 col4" >4920.000000</td>
#       <td id="T_ec80a_row0_col5" class="data row0 col5" >3936.000000</td>
#       <td id="T_ec80a_row0_col6" class="data row0 col6" >4400.000000</td>
#       <td id="T_ec80a_row0_col7" class="data row0 col7" >3520.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ec80a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ec80a_row1_col0" class="data row1 col0" >2023-08-10</td>
#       <td id="T_ec80a_row1_col1" class="data row1 col1" >porte_a</td>
#       <td id="T_ec80a_row1_col2" class="data row1 col2" >4400.000000</td>
#       <td id="T_ec80a_row1_col3" class="data row1 col3" >5</td>
#       <td id="T_ec80a_row1_col4" class="data row1 col4" >4920.000000</td>
#       <td id="T_ec80a_row1_col5" class="data row1 col5" >3936.000000</td>
#       <td id="T_ec80a_row1_col6" class="data row1 col6" >4400.000000</td>
#       <td id="T_ec80a_row1_col7" class="data row1 col7" >3520.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ec80a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ec80a_row2_col0" class="data row2 col0" >2023-08-17</td>
#       <td id="T_ec80a_row2_col1" class="data row2 col1" >porte_a</td>
#       <td id="T_ec80a_row2_col2" class="data row2 col2" >3600.000000</td>
#       <td id="T_ec80a_row2_col3" class="data row2 col3" >5</td>
#       <td id="T_ec80a_row2_col4" class="data row2 col4" >4920.000000</td>
#       <td id="T_ec80a_row2_col5" class="data row2 col5" >3936.000000</td>
#       <td id="T_ec80a_row2_col6" class="data row2 col6" >4133.333333</td>
#       <td id="T_ec80a_row2_col7" class="data row2 col7" >3306.666667</td>
#     </tr>
#     <tr>
#       <th id="T_ec80a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ec80a_row3_col0" class="data row3 col0" >2023-08-24</td>
#       <td id="T_ec80a_row3_col1" class="data row3 col1" >porte_a</td>
#       <td id="T_ec80a_row3_col2" class="data row3 col2" >4700.000000</td>
#       <td id="T_ec80a_row3_col3" class="data row3 col3" >5</td>
#       <td id="T_ec80a_row3_col4" class="data row3 col4" >4920.000000</td>
#       <td id="T_ec80a_row3_col5" class="data row3 col5" >3936.000000</td>
#       <td id="T_ec80a_row3_col6" class="data row3 col6" >4275.000000</td>
#       <td id="T_ec80a_row3_col7" class="data row3 col7" >3420.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ec80a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ec80a_row4_col0" class="data row4 col0" >2023-08-31</td>
#       <td id="T_ec80a_row4_col1" class="data row4 col1" >porte_a</td>
#       <td id="T_ec80a_row4_col2" class="data row4 col2" >4700.000000</td>
#       <td id="T_ec80a_row4_col3" class="data row4 col3" >5</td>
#       <td id="T_ec80a_row4_col4" class="data row4 col4" >4920.000000</td>
#       <td id="T_ec80a_row4_col5" class="data row4 col5" >3936.000000</td>
#       <td id="T_ec80a_row4_col6" class="data row4 col6" >4360.000000</td>
#       <td id="T_ec80a_row4_col7" class="data row4 col7" >3488.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ec80a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ec80a_row5_col0" class="data row5 col0" >2023-08-01</td>
#       <td id="T_ec80a_row5_col1" class="data row5 col1" >porte_a</td>
#       <td id="T_ec80a_row5_col2" class="data row5 col2" >4200.000000</td>
#       <td id="T_ec80a_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_ec80a_row5_col4" class="data row5 col4" >4920.000000</td>
#       <td id="T_ec80a_row5_col5" class="data row5 col5" >3936.000000</td>
#       <td id="T_ec80a_row5_col6" class="data row5 col6" >4200.000000</td>
#       <td id="T_ec80a_row5_col7" class="data row5 col7" >3360.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ec80a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ec80a_row6_col0" class="data row6 col0" >2023-08-08</td>
#       <td id="T_ec80a_row6_col1" class="data row6 col1" >porte_a</td>
#       <td id="T_ec80a_row6_col2" class="data row6 col2" >4700.000000</td>
#       <td id="T_ec80a_row6_col3" class="data row6 col3" >3</td>
#       <td id="T_ec80a_row6_col4" class="data row6 col4" >4920.000000</td>
#       <td id="T_ec80a_row6_col5" class="data row6 col5" >3936.000000</td>
#       <td id="T_ec80a_row6_col6" class="data row6 col6" >4450.000000</td>
#       <td id="T_ec80a_row6_col7" class="data row6 col7" >3560.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ec80a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ec80a_row7_col0" class="data row7 col0" >2023-08-15</td>
#       <td id="T_ec80a_row7_col1" class="data row7 col1" >porte_a</td>
#       <td id="T_ec80a_row7_col2" class="data row7 col2" >4200.000000</td>
#       <td id="T_ec80a_row7_col3" class="data row7 col3" >3</td>
#       <td id="T_ec80a_row7_col4" class="data row7 col4" >4920.000000</td>
#       <td id="T_ec80a_row7_col5" class="data row7 col5" >3936.000000</td>
#       <td id="T_ec80a_row7_col6" class="data row7 col6" >4366.666667</td>
#       <td id="T_ec80a_row7_col7" class="data row7 col7" >3493.333333</td>
#     </tr>
#     <tr>
#       <th id="T_ec80a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ec80a_row8_col0" class="data row8 col0" >2023-08-22</td>
#       <td id="T_ec80a_row8_col1" class="data row8 col1" >porte_a</td>
#       <td id="T_ec80a_row8_col2" class="data row8 col2" >4900.000000</td>
#       <td id="T_ec80a_row8_col3" class="data row8 col3" >3</td>
#       <td id="T_ec80a_row8_col4" class="data row8 col4" >4920.000000</td>
#       <td id="T_ec80a_row8_col5" class="data row8 col5" >3936.000000</td>
#       <td id="T_ec80a_row8_col6" class="data row8 col6" >4500.000000</td>
#       <td id="T_ec80a_row8_col7" class="data row8 col7" >3600.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ec80a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ec80a_row9_col0" class="data row9 col0" >2023-08-29</td>
#       <td id="T_ec80a_row9_col1" class="data row9 col1" >porte_a</td>
#       <td id="T_ec80a_row9_col2" class="data row9 col2" >4750.000000</td>
#       <td id="T_ec80a_row9_col3" class="data row9 col3" >3</td>
#       <td id="T_ec80a_row9_col4" class="data row9 col4" >4920.000000</td>
#       <td id="T_ec80a_row9_col5" class="data row9 col5" >3936.000000</td>
#       <td id="T_ec80a_row9_col6" class="data row9 col6" >4550.000000</td>
#       <td id="T_ec80a_row9_col7" class="data row9 col7" >3640.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ec80a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ec80a_row10_col0" class="data row10 col0" >2023-08-04</td>
#       <td id="T_ec80a_row10_col1" class="data row10 col1" >porte_a</td>
#       <td id="T_

# %% [markdown]
# ## Multiples clauses dans le OVER()

# %% [markdown]
# Attention !
#
# Il se trouve que la dataframe était ordonée par date, mais rien ne garantit que ce sera toujours le cas!
#
# Que se passerait-il si les jours n'étaient pas correctement ordonnés?

# %%
shuffled = capteurs.sample(len(capteurs))
query = """
SELECT *,
AVG(visiteurs_count) OVER(
    PARTITION BY weekday 
    ROWS BETWEEN 6 PRECEDING 
    AND CURRENT ROW
    ) AS avg_last_seven_same_days,
avg_last_seven_same_days * 0.8 as threshold
FROM shuffled
WHERE weekday = 7
-- ORDER BY date
"""
df = duckdb.sql(query).df()
df
# Out:
#          date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0  2023-08-19    porte_a           5500.0        7           4920.0
# 1  2023-08-12    porte_a           6000.0        7           4920.0
# 2  2023-08-05    porte_a           6000.0        7           4920.0
# 3  2023-09-02    porte_a           4000.0        7           4700.0
# 4  2023-08-26    porte_a           6000.0        7           4920.0
#
#    threshold_twenty_pct  avg_last_seven_same_days    threshold
# 0                3936.0               5500.000000  4400.000000
# 1                3936.0               5750.000000  4600.000000
# 2                3936.0               5833.333333  4666.666667
# 3                3760.0               5375.000000  4300.000000
# 4                3936.0               5500.000000  4400.000000

# %% [markdown]
# Pour être sur que les données sont correctement triées <b> avant </b> de calculer les indicateurs, il faut utiliser ORDER BY _à l'intérieur_ de la clause OVER.
#
# Vous savez comment faire ça, à vous de jouer:

# %%
query = """
SELECT
    *,
    AVG(visiteurs_count) OVER(PARTITION BY weekday ORDER BY date ROWS BETWEEN 6 PRECEDING and CURRENT ROW) AS avg_last_seven_same_days,
    avg_last_seven_same_days * 0.8 AS threshold
FROM shuffled

"""
duckdb.sql(query).df()
# Out:
#           date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0   2023-08-03    porte_a           4400.0        5           4920.0
# 1   2023-08-10    porte_a           4400.0        5           4920.0
# 2   2023-08-17    porte_a           3600.0        5           4920.0
# 3   2023-08-24    porte_a           4700.0        5           4920.0
# 4   2023-08-31    porte_a           4700.0        5           4920.0
# 5   2023-08-07    porte_a           4200.0        2           4920.0
# 6   2023-08-14    porte_a           3900.0        2           4920.0
# 7   2023-08-21    porte_a           4300.0        2           4920.0
# 8   2023-08-28    porte_a           4300.0        2           4920.0
# 9   2023-09-04    porte_a           4500.0        2           4700.0
# 10  2023-08-02    porte_a           5300.0        4           4920.0
# 11  2023-08-09    porte_a           5300.0        4           4920.0
# 12  2023-08-16    porte_a           4700.0        4           4920.0
# 13  2023-08-23    porte_a           5500.0        4           4920.0
# 14  2023-08-30    porte_a           5500.0        4           4920.0
# 15  2023-08-05    porte_a           6000.0        7           4920.0
# 16  2023-08-12    porte_a           6000.0        7           4920.0
# 17  2023-08-19    porte_a           5500.0        7           4920.0
# 18  2023-08-26    porte_a           6000.0        7           4920.0
# 19  2023-09-02    porte_a           4000.0        7           4700.0
# 20  2023-08-01    porte_a           4200.0        3           4920.0
# 21  2023-08-08    porte_a           4700.0        3           4920.0
# 22  2023-08-15    porte_a           4200.0        3           4920.0
# 23  2023-08-22    porte_a           4900.0        3           4920.0
# 24  2023-08-29    porte_a           4750.0        3           4920.0
# 25  2023-08-04    porte_a           5500.0        6           4920.0
# 26  2023-08-11    porte_a           5500.0        6           4920.0
# 27  2023-08-18    porte_a           5000.0        6           4920.0
# 28  2023-08-25    porte_a           5800.0        6           4920.0
# 29  2023-09-01    porte_a           5600.0        6           4700.0
#
#     threshold_twenty_pct  avg_last_seven_same_days    threshold
# 0                 3936.0               4400.000000  3520.000000
# 1                 3936.0               4400.000000  3520.000000
# 2                 3936.0               4133.333333  3306.666667
# 3                 3936.0               4275.000000  3420.000000
# 4                 3936.0               4360.000000  3488.000000
# 5                 3936.0               4200.000000  3360.000000
# 6                 3936.0               4050.000000  3240.000000
# 7                 3936.0               4133.333333  3306.666667
# 8                 3936.0               4175.000000  3340.000000
# 9                 3760.0               4240.000000  3392.000000
# 10                3936.0               5300.000000  4240.000000
# 11                3936.0               5300.000000  4240.000000
# 12                3936.0               5100.000000  4080.000000
# 13                3936.0               5200.000000  4160.000000
# 14                3936.0               5260.000000  4208.000000
# 15                3936.0               6000.000000  4800.000000
# 16                3936.0               6000.000000  4800.000000
# 17                3936.0               5833.333333  4666.666667
# 18                3936.0               5875.000000  4700.000000
# 19                3760.0               5500.000000  4400.000000
# 20                3936.0               4200.000000  3360.000000
# 21                3936.0               4450.000000  3560.000000
# 22                3936.0               4366.666667  3493.333333
# 23                3936.0               4500.000000  3600.000000
# 24                3936.0               4550.000000  3640.000000
# 25                3936.0               5500.000000  4400.000000
# 26                3936.0               5500.000000  4400.000000
# 27                3936.0               5333.333333  4266.666667
# 28                3936.0               5450.000000  4360.000000
# 29                3760.0               5480.000000  4384.000000

# %%
# %load solutions/12partitionby_orderby.py
shuffled = capteurs.sample(len(capteurs))
query = """
SELECT *,
AVG(visiteurs_count) OVER(
    PARTITION BY weekday 
    ORDER BY date
    ROWS BETWEEN 6 PRECEDING 
    AND CURRENT ROW
    ) AS avg_last_seven_same_days,
avg_last_seven_same_days * 0.8 as threshold
FROM shuffled
WHERE weekday = 7
"""
df = duckdb.sql(query).df()
df
# Out:
#          date capteur_id  visiteurs_count  weekday  moyenne_du_mois  \
# 0  2023-08-05    porte_a           6000.0        7           4920.0
# 1  2023-08-12    porte_a           6000.0        7           4920.0
# 2  2023-08-19    porte_a           5500.0        7           4920.0
# 3  2023-08-26    porte_a           6000.0        7           4920.0
# 4  2023-09-02    porte_a           4000.0        7           4700.0
#
#    threshold_twenty_pct  avg_last_seven_same_days    threshold
# 0                3936.0               6000.000000  4800.000000
# 1                3936.0               6000.000000  4800.000000
# 2                3936.0               5833.333333  4666.666667
# 3                3936.0               5875.000000  4700.000000
# 4                3760.0               5500.000000  4400.000000

# %% [markdown]
# ### Conclusion

# %% [markdown]
# On a résolu le problème initial: récupérer la moyenne glissante (ou mobile) <br />
# sur les 7 derniers jours similaires <br />
# pour comparer les Mardi avec les Mardi et les Samedi avec les Samedi <br />
# et avoir des seuils qui ont du sens

# %% [markdown]
# <blockquote> Ouais, par contre ta requête pour avoir le 2e meilleur salaire par département, il n'y aurait pas moyen de l'améliorer un peu ? </blockquote>
#
# Si ! On va voir avec quelle clause dans le prochain notebook ;)
